# %%
from IPython.display import display_html
import xml.etree.ElementTree as et 
import pandas as pd
import numpy as np
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Circle, Rectangle, Arc
import logging
import math

# %%
#main Function
TeamDF = preparingDataAndDF()


#TeamDF = TeamDF.loc[TeamDF['round'] < 3]
#big4 = ['sagesse', 'riyadi','dynamo','beirut']
#BIG4 = ['Sagesse', 'Riyadi','Dynamo','Beirut']
round = ["6","7","8","9","10","11"]
#TeamDF = TeamDF.loc[TeamDF['round'].str.contains('|'.join(round))]
#CriteriaDF =  TeamDF.loc[TeamDF['team'].str.contains('Riyadi')&TeamDF['oponent'].str.contains('|'.join(big4))]
#CriteriaBig4 =  TeamDF.loc[TeamDF['team'].str.contains('NSA')&TeamDF['oponent'].str.contains('|'.join(big4))]

#toPlotDF = TeamDF.loc[TeamDF['type'].str.contains('floating')&TeamDF['distance'].str.contains('2pt')&TeamDF['player'].str.contains('Harris')]
#regular_plot(CriteriaDF)
#plot(CriteriaBig4)

#CriteriaDF =  TeamDF.loc[TeamDF['zone'].str.contains('Left of the key')]
#CriteriaBig4 =  TeamDF.loc[TeamDF['player'].str.contains('A. Ibrahim')&TeamDF['oponent'].str.contains('|'.join(big4))]
#regular_plot(CriteriaBig4)
#CriteriaDF['oponent'].unique()
#testZoneDF =  TeamDF.loc[TeamDF['player'].str.contains('Malla')]

#HomeGamesDF = TeamDF.loc[TeamDF['Home/Away'].str.contains('Home')]
#AwayGamesDF = TeamDF.loc[TeamDF['Home/Away'].str.contains('Away')]
#regular_plot(haidarchart)
#plotdelete(CriteriaDF,1)

#test = getDunksDF(CriteriaDF)
#test

summers = TeamDF.loc[TeamDF['player'].str.contains("Rusto")]
regular_plot(summers)


TeamDF['player'].unique()
# Out:
# array([' D. Ochefu', ' K. Merphy', ' K. Zeinoun', ' W. Arakji',
#        ' H. Gyokochian', ' J. Abdel Nour', ' I. Ahmad', ' A. Saoud',
#        ' A. Haidar', ' R. Akl', ' M. Shabaz', ' E. Rustom', ' K. Hayes',
#        ' G. Hadidian', ' K. Mechref'], dtype=object)

# %%
zoneavg = TeamDF.loc[TeamDF['team'].str.contains('Byblos')]
zoneavg['round'].value_counts()
# Out:
# 11    76
# 3     73
# 4     68
# 8     63
# 6     63
# 1     61
# 5     61
# 9     59
# 2     53
# 10    52
# Name: round, dtype: int64

# %%
TeamDF['team'].value_counts()
# Out:
# Atlas         810
# Dynamo        803
# NSA           788
# Beirut        783
# Sagesse       775
# Riyadi        766
# Mariste       762
# Leaders       758
# Hoops         755
# Homenetmen    739
# Antranik      732
# Byblos        629
# Name: team, dtype: int64

# %%
HomeGames_df = TeamDF.loc[TeamDF['Home/Away'].str.contains('Away')]
HomeGames_df
##teams
RightOfTheKeythree_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Right of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


RightOfTheKeythree_grouped_teams = RightOfTheKeythree_df_teams.groupby('team')
madeRightOfTheKeythree = RightOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeyThree = RightOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightOfTheKeythree_final_teams = pd.concat([madeRightOfTheKeythree,totalRightOfTheKeyThree],axis ='columns').reset_index()
RightOfTheKeythree_final_teams['Percentage'] = RightOfTheKeythree_final_teams['made']/RightOfTheKeythree_final_teams['total']*100
RightOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightOfTheKeythree_final_teams.head(20).to_csv('processed/teams/RightOfTheKeythree_final_teams.csv')

LeftOfTheKeythree_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Left of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftOfTheKeythree_grouped_teams = LeftOfTheKeythree_df_teams.groupby('team')
madeLeftOfTheKeythree = LeftOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftOfTheKeyThree = LeftOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftOfTheKeythree_final_teams = pd.concat([madeLeftOfTheKeythree,totalLeftOfTheKeyThree],axis ='columns').reset_index()
LeftOfTheKeythree_final_teams['Percentage'] = LeftOfTheKeythree_final_teams['made']/LeftOfTheKeythree_final_teams['total']*100
LeftOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftOfTheKeythree_final_teams.head(20).to_csv('processed/teams/LeftOfTheKeythree_final_teams.csv')

 
TopOfTheKeythree_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Top of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


TopOfTheKeythree_grouped_teams = TopOfTheKeythree_df_teams.groupby('team')
madeTopOfTheKeythree = TopOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopOfTheKeyThree = TopOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

TopOfTheKeythree_final_teams = pd.concat([madeTopOfTheKeythree,totalTopOfTheKeyThree],axis ='columns').reset_index()
TopOfTheKeythree_final_teams['Percentage'] = TopOfTheKeythree_final_teams['made']/TopOfTheKeythree_final_teams['total']*100
TopOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopOfTheKeythree_final_teams.head(20).to_csv('processed/teams/TopOfTheKeythree_final_teams.csv')



RightCornerthree_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Right Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()
RightCornerthree_grouped_teams = RightCornerthree_df_teams.groupby('team')
madeRightCornerthree = RightCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightCornerThree = RightCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
RightCornerthree_final_teams = pd.concat([madeRightCornerthree,totalRightCornerThree],axis ='columns').reset_index()
RightCornerthree_final_teams['Percentage'] = RightCornerthree_final_teams['made']/RightCornerthree_final_teams['total']*100
RightCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightCornerthree_final_teams.head(20).to_csv('processed/teams/RightCornerTeams.csv')


 
LeftCornerthree_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Left Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftCornerthree_grouped_teams = LeftCornerthree_df_teams.groupby('team')
madeLeftCornerthree = LeftCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftCornerThree = LeftCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftCornerthree_final_teams = pd.concat([madeLeftCornerthree,totalLeftCornerThree],axis ='columns').reset_index()
LeftCornerthree_final_teams['Percentage'] = LeftCornerthree_final_teams['made']/LeftCornerthree_final_teams['total']*100
LeftCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftCornerthree_final_teams.head(20).to_csv('processed/teams/LeftCorner.csv')



 
Restricted_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()


Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20).to_csv('processed/teams/Restricted.csv')



 
Restricted_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()
Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20)




 
InsideThePaint_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Inside the paint')]
#RightOfTheKeythree['team'].value_counts()


InsideThePaint_grouped_teams = InsideThePaint_df_teams.groupby('team')
madeInsideThePaint = InsideThePaint_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalInsideThePaint = InsideThePaint_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

InsideThePaint_final_teams = pd.concat([madeInsideThePaint,totalInsideThePaint],axis ='columns').reset_index()
InsideThePaint_final_teams['Percentage'] = InsideThePaint_final_teams['made']/InsideThePaint_final_teams['total']*100
InsideThePaint_final_teams.sort_values(by='made', ascending=False, inplace=True)
InsideThePaint_final_teams.head(20).to_csv('processed/teams/InsidethePaint.csv')




 
RightMidrange_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Right midrange')]
#RightOfTheKeythree['team'].value_counts()


RightMidrange_grouped_teams = RightMidrange_df_teams.groupby('team')
madeRightMidrange = RightMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightMidrange = RightMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightMidrange_final_teams = pd.concat([madeRightMidrange,totalRightMidrange],axis ='columns').reset_index()
RightMidrange_final_teams['Percentage'] = RightMidrange_final_teams['made']/RightMidrange_final_teams['total']*100
RightMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightMidrange_final_teams.head(20).to_csv('processed/teams/RightMidTeam.csv')


 
LeftMidrange_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Left midrange')]
#RightOfTheKeythree['team'].value_counts()


LeftMidrange_grouped_teams = LeftMidrange_df_teams.groupby('team')
madeLeftMidrange = LeftMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftMidrange = LeftMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftMidrange_final_teams = pd.concat([madeLeftMidrange,totalLeftMidrange],axis ='columns').reset_index()
LeftMidrange_final_teams['Percentage'] = LeftMidrange_final_teams['made']/LeftMidrange_final_teams['total']*100
LeftMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftMidrange_final_teams.head(20).to_csv('processed/teams/LeftMidrangeTeam.csv')




TopMidrange_df_teams = HomeGames_df.loc[HomeGames_df['zone'].str.contains('Top of the midrange')]
#RightOfTheKeythree['team'].value_counts()
TopMidrange_grouped_teams = TopMidrange_df_teams.groupby('team')
madeTopMidrange = TopMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopMidrange = TopMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
TopMidrange_final_teams = pd.concat([madeTopMidrange,totalTopMidrange],axis ='columns').reset_index()
TopMidrange_final_teams['Percentage'] = TopMidrange_final_teams['made']/TopMidrange_final_teams['total']*100
TopMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopMidrange_final_teams.head(20).to_csv('processed/teams/TopMidrange.csv')

LeftCornerthree_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 3       Byblos     6     11   54.545455
# 1        Atlas     4     12   33.333333
# 4       Dynamo     4      7   57.142857
# 5   Homenetmen     4      9   44.444444
# 10      Riyadi     4      9   44.444444
# 11     Sagesse     4     15   26.666667
# 0     Antranik     3      4   75.000000
# 2       Beirut     3      6   50.000000
# 8      Mariste     2      7   28.571429
# 9          NSA     2      7   28.571429
# 7      Leaders     1      3   33.333333
# 6        Hoops     0      5    0.000000

# %%
Criteria2['zone'].value_counts()
# Out:
# Restricted Area         27
# Left of the key 3pt      4
# Right of the key 3pt     4
# Inside the paint         2
# Top of the key 3pt       2
# Left midrange 2pt        1
# Left Corner 3pt          1
# Top of the midrange      1
# Name: zone, dtype: int64

# %%
cliff = TeamDF.loc[TeamDF['player'].str.contains('Alexa')& TeamDF['made'].str.contains('made')]
cliff['zone'].value_counts()
# Out:
# Restricted Area         66
# Inside the paint         6
# Top of the key 3pt       5
# Right of the key 3pt     2
# Left midrange 2pt        2
# Right midrange           1
# Top of the midrange      1
# Left of the key 3pt      1
# Name: zone, dtype: int64

# %%
CriteriaDF =  TeamDF.loc[TeamDF['team'].str.contains('Sagesse')&TeamDF['oponent'].str.contains('|'.join(big4))]
regular_plot(CriteriaDF)

# %%
TeamDF.loc[TeamDF['type'].str.contains('lay')]['player'].value_counts()
# Out:
#  J. Salem           73
#  M. Carter          68
#  I. Hammon          68
#  J. Jones           42
#  I. Haddad          42
#                     ..
#  T. Baxter Jr.       1
#  S. Khattab          1
#  M. Komayha          1
#  J. Abdel Massih     1
#  K. Ouwedet          1
# Name: player, Length: 163, dtype: int64

# %%
floaters = getFloatersDF(TeamDF)
floaters.head(20)
# Out:
#             player level_1  made   0
# 175      W. Sidney       5   3.0 NaN
# 48      G. Daaboul      10   3.0 NaN
# 177      W. Sidney       9   3.0 NaN
# 84        J. Salem      10   2.0 NaN
# 157       R. Saeed       9   2.0 NaN
# 156       R. Saeed       8   2.0 NaN
# 135        M. Skaf       5   2.0 NaN
# 168    V. Bermudez      11   2.0 NaN
# 55       G. Souaid      11   2.0 NaN
# 59       I. Hammon       2   2.0 NaN
# 169    V. Bermudez       9   2.0 NaN
# 70    J. Dontarios       8   2.0 NaN
# 71        J. Dwayn       2   2.0 NaN
# 117       M. Dixon       2   2.0 NaN
# 180    Y. Ghantous       5   2.0 NaN
# 181    Y. Ghantous       6   2.0 NaN
# 79        J. Jones      10   2.0 NaN
# 185      Z. Lofton       2   2.0 NaN
# 95       J. Zaloum       9   2.0 NaN
# 102        K. Rush       9   1.0 NaN

# %%
CriteriaDF = TeamDF.loc[TeamDF['player'].str.contains('Ghantous')&TeamDF['type'].str.contains('floating')]
regular_plot(CriteriaDF)

# %%
def getFloatersDF(df):
    floaters_df = df.loc[df['type'] == 'floating']
    floaters_grouped = floaters_df.groupby('player')
    madefloaters = floaters_grouped['made'].apply(lambda x: x.str.contains('made').sum())
    totalfloaters = floaters_df.groupby('player').size()
    #totalflaoaters
    test = pd.concat([madefloaters,totalfloaters],axis ='columns').reset_index()
    test.sort_values(by = 'made',inplace=True, ascending = False)
    return test

# %%
fl=TeamDF.loc[TeamDF['player'].str.contains('Gyok')&TeamDF['distance'].str.contains('2')]
regular_plot(fl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11164\2818463891.py in <module>
# ----> 1 fl=TeamDF.loc[TeamDF['player'].str.contains('Gyok')&TeamDF['distance'].str.contains('2')]
#       2 regular_plot(fl)
#
# NameError: name 'TeamDF' is not defined

# %%
def getDunksDF(df):
    Dunks_df = df.loc[TeamDF['type'] == 'dunk']
    Dunks_grouped = Dunks_df.groupby('player')
    madeDunks = Dunks_grouped['made'].apply(lambda x: x.str.contains('made').sum())
    totalDunks = Dunks_df.groupby('player').size()
    #totalflaoaters
    test = pd.concat([madeDunks,totalDunks],axis ='columns').reset_index()
    test.sort_values(by = 'made',inplace=True, ascending = False)
    return test

# %%
def getStepBackDF(df):
    StepBack_df = df.loc[TeamDF['type'] == 'step']
    StepBack_grouped = StepBack_df.groupby('player')
    madeStepBack = StepBack_grouped['made'].apply(lambda x: x.str.contains('made').sum())
    totalStepBack = StepBack_df.groupby('player').size()
    #totalflaoaters
    test2 = pd.concat([madeStepBack,totalStepBack],axis ='columns').reset_index()
    test2.sort_values(by = 'made',inplace=True, ascending = False)
    return test2

# %%
def getJumpShot(df):
    jumpshot_df = df.loc[TeamDF['type'] == 'jump']
    jumpshot_grouped = jumpshot_df.groupby('player')
    madejumpshot = jumpshot_grouped['made'].apply(lambda x: x.str.contains('made').sum())
    totaljumpshot = jumpshot_df.groupby('player').size()
    #totalflaoaters
    sb_df = pd.concat([madejumpshot,totaljumpshot],axis ='columns').reset_index()
    sb_df.sort_values(by = 'made',inplace=True, ascending = False)
    return sb_df

# %%
def getZone(left,bottom,distance):
    
    if (left>660) and (bottom<=147.5):
        return 'Right Corner '+distance
    
    elif ((left<-660) and (bottom<=147.5)):
        return 'Left Corner '+distance
    
    elif (-300<left<300) and ('3pt' in distance) and (bottom>147.5):
        return 'Top of the key '+distance
    
    elif (left>=300) and ('3pt' in distance) and (bottom>=147.5):
        return 'Right of the key '+distance
    elif (left<=-300) and ('3pt' in distance):
        return 'Left of the key '+distance
    
    elif -660<=left<=-490/2 and distance =='2pt':
        return 'Left midrange '+distance
    elif -490/2<= left <=490/2 and 400<=bottom<=600 and distance =='2pt':
        return 'Top of the midrange'
    
    elif 490/2<=left <=660 and distance =='2pt':
        return 'Right midrange'
    elif isRestrictedArea(left,bottom):
        return 'Restricted Area'
    
    elif -245<=left <=245 and bottom <=422.5:
        return 'Inside the paint'
    else:
        return 'to be checked'


###### Floaters and shit 
## to add the percentage later 






#test.iloc[0,1]
#test.iloc[2].astype(int)
#test.iloc[3].astype(int)
#test.rename(columns={'made':'Number of Made Floaters',0:'Number of attempts'})
#test['Pct']=int(test.iloc[2])/int(test.iloc[3])

# %%
def isRestrictedArea(left,bottom):
    #this is based on the distance formula, in cercles all the points have the same distance from the center
    #so we will apply this here
    tmpsum = left*left+bottom*bottom
    distance= math.sqrt(tmpsum)
    if(distance <125):
        return True
    else:
        return False

# %%
def preparingDataAndDF(team='all'):
    
    #file='data/dynamogame.xml'
    #file='data/shot-chart-'+team+'.xml'
    #file='data/summers.xml'
    file='data/brahima.xml'
    df_cols = ["player", "team", "oponent", "left", "bottom","made","type","distance","Home/Away",'zone','round']
    rows = []
    xtree = et.parse(file)
    #root = xtree.getroot().getchildren()
    root = list(xtree.getroot())
    #rint(len(root))
    for xroot in root:
        
        team = xroot.attrib.get("id")
        #print(team)
        for node in xroot: 
            #parsing the  data
            s_class = node.attrib.get("class")
            s_style = node.attrib.get("style")
            s_title = node.attrib.get("title")
            s_oponent = node.attrib.get("alt")
            s_round = node.attrib.get("round")
            
            #retrieving the data
            
            #int_round = int(s_round)
            
            
            df_player = getPlayer(s_title)
            #rint(df_player)

            df_type = getType(s_title)
            df_made = getMade(s_class)
            coordinate = getCoordinate(s_style)

            #df_left = coordinate[0]
            #df_bottom = coordinate[1]
            df_left = coordinate[1]
            df_bottom = coordinate[0]
            df_homeAway = getHomeAway(s_class)
        
            zone=getZone(df_left,df_bottom,df_type[1])

            rows.append({"player": df_player, "team": team, "Home/Away":df_homeAway, "round":s_round,
                         "bottom": df_bottom,"left": df_left, "oponent":s_oponent, "made":df_made,"type":df_type[2],"distance":df_type[1],"zone":zone})

    #rows.append({"player": 'test', "team": 'test', 
                         #"bottom": -400,"left": 600, "made":'df_made',"type":'df_type[2]',"distance":'df_type[1]'})
    #rows.append({"player": 'test', "team": 'test', 
                         #"bottom": -701,"left": 148, "made":'df_made',"type":'df_type[2]',"distance":'df_type[1]'})
    TeamDF = pd.DataFrame(rows, columns = df_cols)
        #playerDF= TeamDF.loc[TeamDF['player'].str.contains('Haidar')]
        #layerDF = 'dd'
        #eamDF = TeamDF.loc[TeamDF['player'].str.contains('N. Souaid')]
        #eamDF = TeamDF.loc[TeamDF['distance'].str.contains('3pt')]


    made =TeamDF.loc[TeamDF['made'].str.contains('made')]
    missed = TeamDF.loc[TeamDF['made'].str.contains('missed')]

    return TeamDF

# %%
#print(TeamDF.type.unique())

# %%
def getHomeAway(s_class):
    if "white" in s_class:
        return "Home"
    else:
        return "Away"

# %%
def getPlayer(title):
    return title.split(',')[1]
def getType(title):
    #print(title)
    return title.split(',')[2].split(' ')
def getMade(s_class):
    shot=s_class.split(' ')[1].split('_')[1]
    return shot
def checkCoordinate(left,bottom):
    arr = []
    newleft=-1;
    newbottom=-1;
    
    if(left>50):
        left = (100-left)
        #bottom=100-bottom
    else:
        bottom = 100-bottom
    if(bottom<50):
        #Since the bottom part (below 50) is negative, im trying to get the percentages accordingly 
        tmp=1500*bottom/100
        bottom=750-tmp
        bottom = -bottom
    else:
        bottom=1500*(bottom)/100
        bottom=bottom-750
        
        
    
    left=left*2715/100
    left = left-157.5
    if(left<-157.5 + 120-25):
        left=-157.5 + 120-25
    bottom=bottom
    
    arr.append(left)
    #bottom = bottom
    arr.append(bottom)
    return arr


def getpixels(left,bottom):
    
    arr = []
    
    #pixelleft = (720.695*left)/100
    #pixelbottom = (428.812*bottom)/100
    
    pixelleft = (891*left)/100
    pixelbottom = (532*bottom)/100
    if(left>50):
        #pixelleft = 720.695-pixelleft
        #pixelbottom = 428.812-pixelbottom
        pixelleft = 891-pixelleft
        pixelbottom = 532-pixelbottom
        
    pixelleft=pixelleft
    arr.append(pixelleft)
    arr.append(pixelbottom)
    return arr

def getCoordinate(style):
    tmp = style.split(';')
    left= tmp[1].split('%')[0].split(":")[1]
    bottom= tmp[0].split('%')[0].split(":")[1]
    
    return checkCoordinate(float(left),float(bottom))
    #return checkCoordinate(float(bottom),float(left))

# %%
### from matplotlib import pyplot as plt
from matplotlib.patches import Circle, Rectangle, Arc


def draw_court(ax=None, color='white', lw=1, outer_lines=True):
    """
    FIBA basketball court dimensions:
    https://www.msfsports.com.au/basketball-court-dimensions/
    It seems like the Euroleauge API returns the shooting positions
    in resolution of 1cm x 1cm.
    """
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 45.72cm so it has a radius 45.72/2 cms
    hoop = Circle((-0, -25), radius=45.72 / 2, linewidth=lw, color=color,
                  fill=False)

    # Create backboard
    backboard = Rectangle((-90, -157.5 + 120-25), 180, -1, linewidth=lw,
                          color=color)

    # The paint
    # Create the outer box of the paint
    outer_box = Rectangle((-490 / 2, -157.5), 490, 580, linewidth=lw,
                          color=color, fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-360 / 2, -157.5), 360, 580, linewidth=lw,
                          color=color, fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 580 - 157.5), 360, 360, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 580 - 157.5), 360, 360, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 2 * 125, 2 * 125, theta1=0, theta2=180,
                     linewidth=lw, color=color)

    # Three point line
    # Create the side 3pt lines
    corner_three_a = Rectangle((-750 + 90, -157.5), 0, 305, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((750 - 90, -157.5), 0, 305, linewidth=lw,
                               color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the
    # threes
    three_arc = Arc((0, 0), 2 * 675, 2 * 675, theta1=12, theta2=167.5,
                    linewidth=lw, color=color)

    # Center Court
    center_outer_arc = Arc((0, 1400-157.5), 2 * 180, 2 * 180, theta1=180,
                           theta2=0, linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box,
                      restricted, top_free_throw, bottom_free_throw,
                      corner_three_a, corner_three_b, three_arc,
                      center_outer_arc]
    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-750, -157.5), 1500, 1400, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

# %%
def getMakesDF(TeamDF):
    
    TeamDF['shot_made'] = 0
    TeamDF['shot_made'] = TeamDF['shot_made'].mask(TeamDF.made == 'made', 1)
    makes_df = TeamDF[TeamDF.shot_made == 1]
    return makes_df

# %%
def regular_plot(TeamDF, title=None):
    """
    
    Scatter plot of made and missed shots
    """
    
    made =TeamDF.loc[TeamDF['made'].str.contains('made')]
    missed = TeamDF.loc[TeamDF['made'].str.contains('missed')]
    
    plt.figure()
    ax=draw_court()
    #ax.set_facecolor("#1b0b54")
    
    
    
    #plt.plot('650','0','x')
    plt.plot(made['left'], made['bottom'], 'o', label='Made',color='Green')
    plt.plot(missed['left'], missed['bottom'], 'x',label='Missed',color ='Orange')
    plt.legend()

        #ax.set_facecolor("#1b0b54")
    ax.set_facecolor("#10094f")
    cur_axes = plt.gca()
    cur_axes.axes.get_xaxis().set_visible(True)
    cur_axes.axes.get_yaxis().set_visible(True)
    
    img = plt.imread('court.png')
    
    plt.xlim(-800,800)
    plt.ylim(-200,1300)
    #plt.hexbin(x=x_coords, y=y_coords, C=[0] * len(x_coords), gridsize=40, edgecolors='Orange', cmap='Blues')
    #plt.imshow(img, zorder=0, extent=[0, 445.5, 0.0, 532])
    
    plt.title(title)
    
    plt.savefig('processed/floaters.png', dpi=1000)

    
    plt.show()
    return

# %%
def plothexa(TeamDF,Threshold=1):
    
    
    
    makes_df = getMakesDF(TeamDF)
    shots_hex= plt.hexbin(x=TeamDF.left, y=TeamDF.bottom,extent=(-800,800,-200,1200) ,cmap='coolwarm', gridsize=20)
    #added for the 4th dimension, volume of shots
    shots_by_hex=shots_hex.get_array()
    freq_by_hex=shots_by_hex/sum(shots_by_hex)
    sizes = freq_by_hex
    plt.close()



    #plt.ylim(-200, 1400)
    #plt.xlim(-900, 900)

    #efficiency of shots
    makes_hex = plt.hexbin(x=makes_df.left, y=makes_df.bottom, extent=(-800, 800, -200, 1200), gridsize=20)
    plt.close()
    pcts_by_hex = makes_hex.get_array() / shots_hex.get_array()
    pcts_by_hex[np.isnan(pcts_by_hex)] = 0  # convert NAN values to 0

    sample_sizes = shots_hex.get_array()
    filter_threshold = Threshold
    for i in range(len(pcts_by_hex)):
        if sample_sizes[i] < filter_threshold:
            pcts_by_hex[i] = 0
    x = [i[0] for i in shots_hex.get_offsets()]
    y = [i[1] for i in shots_hex.get_offsets()]
    #z = pcts_by_hex
    z = pcts_by_hex *100
    scatter = plt.scatter(x, y, c=z, s=sizes, cmap='Reds', marker='h')

    #plt.imshow(img, zorder=0, extent=[0, 445.5, 0.0, 532])
    #plt.text(, 350, "Shot chart: \nJames Harden ('18-'19)")
    ax = draw_court()
    
    
    ax.set_facecolor("#1b0b54")
   # ax.set_facecolor("#FFFFFF")
    cur_axes = plt.gca()
    cur_axes.axes.get_xaxis().set_visible(False)
    cur_axes.axes.get_yaxis().set_visible(False)
    plt.xlim(-800,800)
    plt.ylim(-200,1300)


    sizes = freq_by_hex
    #sizes = sizes / max(sizes) * 50
    max_freq = max(freq_by_hex)
    max_size = max(sizes)
    
    legend1 = plt.legend(
        *scatter.legend_elements(num=4, fmt="{x:.0f}%"),
        loc="upper right", title='Shot\nacc', fontsize='small')
    legend2 = plt.legend(
        *scatter.legend_elements(
            'sizes', num=4, alpha=0.8, fmt="{x:.1f}%"
            , func=lambda s: s / max_size * max_freq *100
        ),
        loc='upper left', title='Freq (%)', fontsize='small')
    plt.gca().add_artist(legend1)
    #plt.savefig('test.png', dpi=500)

# %%
TeamDF.loc[TeamDF['zone'].str.contains('Left Corner 3')&TeamDF['team'].str.contains('Riyadi')&TeamDF['made'].str.contains('made')]
# Out:
#               player    team oponent        left      bottom  made  type  \
# 6987      B. Tabbara  Riyadi  nobig4 -699.149998  113.457091  made  jump
# 7033      B. Tabbara  Riyadi  nobig4 -711.899986  130.561491  made  jump
# 7196      A. Mansour  Riyadi  nobig4 -689.849997  105.040450  made  jump
# 7278   H. Gyokochian  Riyadi  nobig4 -724.649963   49.925996  made  jump
# 7294       M. Qualls  Riyadi  nobig4 -703.349991   62.686491  made  jump
# 7490         R. Ledo  Riyadi  nobig4 -703.350002   33.092909  made  jump
#
#      distance Home/Away             zone  round
# 6987      3pt      Away  Left Corner 3pt      9
# 7033      3pt      Away  Left Corner 3pt      9
# 7196      3pt      Away  Left Corner 3pt      2
# 7278      3pt      Home  Left Corner 3pt      3
# 7294      3pt      Home  Left Corner 3pt      3
# 7490      3pt      Away  Left Corner 3pt      6

# %%
##### players
RightOfTheKeythree_df = TeamDF.loc[TeamDF['zone'].str.contains('Right of the key 3pt')]
#RightOfTheKeythree['player'].value_counts()
RightOfTheKeythree_grouped = RightOfTheKeythree_df.groupby('player')
madeRightOfTheKeythree = RightOfTheKeythree_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeyThree = RightOfTheKeythree_df.groupby('player').size().to_frame('total')
#totalfloaters
RightOfTheKeythree_final = pd.concat([madeRightOfTheKeythree,totalRightOfTheKeyThree],axis ='columns').reset_index()
RightOfTheKeythree_final['Percentage'] = RightOfTheKeythree_final['made']/RightOfTheKeythree_final['total']*100
RightOfTheKeythree_final.sort_values(by='made', ascending=False, inplace=True)
RightOfTheKeythree_final.head(20).to_csv('RightOfTheKeythree_final.csv')

LeftOfTheKeythree_df = TeamDF.loc[TeamDF['zone'].str.contains('Left of the key 3pt')]
#RightOfTheKeythree['player'].value_counts()


LeftOfTheKeythree_grouped = LeftOfTheKeythree_df.groupby('player')
madeLeftOfTheKeythree = LeftOfTheKeythree_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftOfTheKeyThree = LeftOfTheKeythree_df.groupby('player').size().to_frame('total')
#totalfloaters

LeftOfTheKeythree_final = pd.concat([madeLeftOfTheKeythree,totalLeftOfTheKeyThree],axis ='columns').reset_index()
LeftOfTheKeythree_final['Percentage'] = LeftOfTheKeythree_final['made']/LeftOfTheKeythree_final['total']*100
LeftOfTheKeythree_final.sort_values(by='made', ascending=False, inplace=True)
LeftOfTheKeythree_final.head(20).to_csv('LeftOfTheKeythree_final.csv')

 
TopOfTheKeythree_df = TeamDF.loc[TeamDF['zone'].str.contains('Top of the key 3pt')]
#RightOfTheKeythree['player'].value_counts()


TopOfTheKeythree_grouped = TopOfTheKeythree_df.groupby('player')
madeTopOfTheKeythree = TopOfTheKeythree_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalTopOfTheKeyThree = TopOfTheKeythree_df.groupby('player').size().to_frame('total')
#totalfloaters

TopOfTheKeythree_final = pd.concat([madeTopOfTheKeythree,totalTopOfTheKeyThree],axis ='columns').reset_index()
TopOfTheKeythree_final['Percentage'] = TopOfTheKeythree_final['made']/TopOfTheKeythree_final['total']*100
TopOfTheKeythree_final.sort_values(by='made', ascending=False, inplace=True)
TopOfTheKeythree_final.head(20).to_csv('TopOfTheKeythree_final.csv')


 
RightCornerthree_df = TeamDF.loc[TeamDF['zone'].str.contains('Right Corner 3pt')]
#RightOfTheKeythree['player'].value_counts()


RightCornerthree_grouped = RightCornerthree_df.groupby('player')
madeRightCornerthree = RightCornerthree_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalRightCornerThree = RightCornerthree_df.groupby('player').size().to_frame('total')
#totalfloaters

RightCornerthree_final = pd.concat([madeRightCornerthree,totalRightCornerThree],axis ='columns').reset_index()
RightCornerthree_final['Percentage'] = RightCornerthree_final['made']/RightCornerthree_final['total']*100
RightCornerthree_final.sort_values(by='made', ascending=False, inplace=True)
RightCornerthree_final.head(20).to_csv('Rightcorner.csv')


 
LeftCornerthree_df = TeamDF.loc[TeamDF['zone'].str.contains('Left Corner 3pt')]
#RightOfTheKeythree['player'].value_counts()


LeftCornerthree_grouped = LeftCornerthree_df.groupby('player')
madeLeftCornerthree = LeftCornerthree_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftCornerThree = LeftCornerthree_df.groupby('player').size().to_frame('total')
#totalfloaters

LeftCornerthree_final = pd.concat([madeLeftCornerthree,totalLeftCornerThree],axis ='columns').reset_index()
LeftCornerthree_final['Percentage'] = LeftCornerthree_final['made']/LeftCornerthree_final['total']*100
LeftCornerthree_final.sort_values(by='made', ascending=False, inplace=True)
LeftCornerthree_final.head(20).to_csv('leftcorner.csv')



 
Restricted_df = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['player'].value_counts()


Restricted_grouped = Restricted_df.groupby('player')
madeRestricted = Restricted_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df.groupby('player').size().to_frame('total')
#totalfloaters

Restricted_final = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final['Percentage'] = Restricted_final['made']/Restricted_final['total']*100
Restricted_final.sort_values(by='made', ascending=False, inplace=True)
Restricted_final.head(20).to_csv('restricted.csv')



 
Restricted_df = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['player'].value_counts()


Restricted_grouped = Restricted_df.groupby('player')
madeRestricted = Restricted_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df.groupby('player').size().to_frame('total')
#totalfloaters

Restricted_final = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final['Percentage'] = Restricted_final['made']/Restricted_final['total']*100
Restricted_final.sort_values(by='made', ascending=False, inplace=True)
Restricted_final.head(20)




 
InsideThePaint_df = TeamDF.loc[TeamDF['zone'].str.contains('Inside the paint')]
#RightOfTheKeythree['player'].value_counts()


InsideThePaint_grouped = InsideThePaint_df.groupby('player')
madeInsideThePaint = InsideThePaint_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalInsideThePaint = InsideThePaint_df.groupby('player').size().to_frame('total')
#totalfloaters

InsideThePaint_final = pd.concat([madeInsideThePaint,totalInsideThePaint],axis ='columns').reset_index()
InsideThePaint_final['Percentage'] = InsideThePaint_final['made']/InsideThePaint_final['total']*100
InsideThePaint_final.sort_values(by='made', ascending=False, inplace=True)
InsideThePaint_final.head(20).to_csv('insidethepaint.csv')




 
RightMidrange_df = TeamDF.loc[TeamDF['zone'].str.contains('Right midrange')]
#RightOfTheKeythree['player'].value_counts()


RightMidrange_grouped = RightMidrange_df.groupby('player')
madeRightMidrange = RightMidrange_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalRightMidrange = RightMidrange_df.groupby('player').size().to_frame('total')
#totalfloaters

RightMidrange_final = pd.concat([madeRightMidrange,totalRightMidrange],axis ='columns').reset_index()
RightMidrange_final['Percentage'] = RightMidrange_final['made']/RightMidrange_final['total']*100
RightMidrange_final.sort_values(by='made', ascending=False, inplace=True)
RightMidrange_final.head(20).to_csv('rightmidrange.csv')


 
LeftMidrange_df = TeamDF.loc[TeamDF['zone'].str.contains('Left midrange')]
#RightOfTheKeythree['player'].value_counts()
LeftMidrange_grouped = LeftMidrange_df.groupby('player')
madeLeftMidrange = LeftMidrange_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftMidrange = LeftMidrange_df.groupby('player').size().to_frame('total')
#totalfloaters
LeftMidrange_final = pd.concat([madeLeftMidrange,totalLeftMidrange],axis ='columns').reset_index()
LeftMidrange_final['Percentage'] = LeftMidrange_final['made']/LeftMidrange_final['total']*100
LeftMidrange_final.sort_values(by='made', ascending=False, inplace=True)
LeftMidrange_final.head(20).to_csv('leftmidrange.csv')




 
TopMidrange_df = TeamDF.loc[TeamDF['zone'].str.contains('Top of the midrange')]
#RightOfTheKeythree['player'].value_counts()


TopMidrange_grouped = TopMidrange_df.groupby('player')
madeTopMidrange = TopMidrange_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalTopMidrange = TopMidrange_df.groupby('player').size().to_frame('total')
#totalfloaters

TopMidrange_final = pd.concat([madeTopMidrange,totalTopMidrange],axis ='columns').reset_index()
TopMidrange_final['Percentage'] = TopMidrange_final['made']/TopMidrange_final['total']*100
TopMidrange_final.sort_values(by='made', ascending=False, inplace=True)
TopMidrange_final.head(20).to_csv('topmidgrane.csv')

InsideThePaint_final.head(50)
# Out:
#             player  made  total  Percentage
# 3       A. Fairely    19     34   55.882353
# 58       I. Hammon    12     26   46.153846
# 14      A. Peacock    10     19   52.631579
# 77       J. Zaloum    10     15   66.666667
# 71        J. Jones    10     24   41.666667
# 51       G. Souaid    10     23   43.478261
# 156    Y. Ghantous     9     27   33.333333
# 5        A. Haidar     9     28   32.142857
# 157      Z. Lofton     8     17   47.058824
# 69      J. Jackson     8     17   47.058824
# 97       M. Carter     8     38   21.052632
# 76    J. Willliams     8     21   38.095238
# 25       C. Khalil     8     18   44.444444
# 74        J. Salem     8     36   22.222222
# 154      W. Sidney     8     24   33.333333
# 12      A. Mansour     8     17   47.058824
# 83       K. Horton     7     13   53.846154
# 46      G. Daaboul     7     27   25.925926
# 48     G. Hadidian     7      9   77.777778
# 22    C. Alexander     7     18   38.888889
# ...

# %%
RightOfTheKeythree_df222 = TeamDF.loc[ TeamDF['zone'].str.contains('Restri') ]
RightOfTheKeythree_df_grouped_player = RightOfTheKeythree_df222.groupby('player')
made_RightOfTheKeythree_df = RightOfTheKeythree_df_grouped_player['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeythree = RightOfTheKeythree_df222.groupby('player').size().to_frame('total')
testgroupedRound = TeamDF.groupby('player')
numberOfRounds = testgroupedRound['round'].apply(lambda x: len(x.unique()))
RightOfTheKeythree_df_final222 = pd.concat([made_RightOfTheKeythree_df,totalRightOfTheKeythree,numberOfRounds],axis='columns').reset_index()
RightOfTheKeythree_df_final222['Percentage'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['total']*100
RightOfTheKeythree_df_final222['madeperround'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['round']
RightOfTheKeythree_df_final222.sort_values(by='madeperround', ascending=False, inplace=True)

RightOfTheKeythree_df_final222.head(20)
# Out:
#              player  made  total  round  Percentage  madeperround
# 24     C. Alexander  81.0  106.0     11   76.415094      7.363636
# 76       J. Jackson  40.0   53.0      6   75.471698      6.666667
# 117       M. Qualls  32.0   41.0      5   78.048780      6.400000
# 97          K. Rush  67.0   91.0     11   73.626374      6.090909
# 39       D. Stanley  12.0   17.0      2   70.588235      6.000000
# 106       M. Carter  58.0   81.0     10   71.604938      5.800000
# 71      J. Caldwell  16.0   26.0      3   61.538462      5.333333
# 20        A. Walker  10.0   14.0      2   71.428571      5.000000
# 154   T. Baxster Jr  14.0   17.0      3   82.352941      4.666667
# 82         J. Salem  51.0   80.0     11   63.750000      4.636364
# 99         K. Smith  23.0   42.0      5   54.761905      4.600000
# 15       A. Peacock  32.0   44.0      7   72.727273      4.571429
# 74         J. Dwayn  32.0   51.0      7   62.745098      4.571429
# ...

# %%
RightOfTheKeythree_df222 = TeamDF.loc[ TeamDF['type'].str.contains('dunk')]
RightOfTheKeythree_df_grouped_player = RightOfTheKeythree_df222.groupby('player')
made_RightOfTheKeythree_df = RightOfTheKeythree_df_grouped_player['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeythree = RightOfTheKeythree_df222.groupby('player').size().to_frame('total')
testgroupedRound = TeamDF.groupby('player')
numberOfRounds = testgroupedRound['round'].apply(lambda x: len(x.unique()))
RightOfTheKeythree_df_final222 = pd.concat([made_RightOfTheKeythree_df,totalRightOfTheKeythree,numberOfRounds],axis='columns').reset_index()
RightOfTheKeythree_df_final222['Percentage'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['total']*100
RightOfTheKeythree_df_final222['madeperround'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['round']
RightOfTheKeythree_df_final222.sort_values(by='madeperround', ascending=False, inplace=True)

RightOfTheKeythree_df_final222.head(20)
# Out:
#             player  made  total  round  Percentage  madeperround
# 10    C. Alexander  50.0   51.0     11   98.039216      4.545455
# 36       M. Qualls  16.0   16.0      5  100.000000      3.200000
# 8        A. Walker   6.0    7.0      2   85.714286      3.000000
# 27      J. Jackson  17.0   18.0      6   94.444444      2.833333
# 46   T. Baxster Jr   7.0    7.0      3  100.000000      2.333333
# 6         A. Majok  22.0   22.0     11  100.000000      2.000000
# 47   T. Baxter Jr.   2.0    3.0      1   66.666667      2.000000
# 31         K. Rush  21.0   23.0     11   91.304348      1.909091
# 1       A. Fairely  19.0   23.0     11   82.608696      1.727273
# 32        K. Smith   8.0    8.0      5  100.000000      1.600000
# 37         M. Ruot   9.0   11.0      6   81.818182      1.500000
# 15      D. Stanley   3.0    4.0      2   75.000000      1.500000
# 38        N. Evans   5.0    5.0      4  100.000000      1.250000
# ...

# %%
RightOfTheKeythree_df222 = TeamDF.loc[TeamDF['type'].str.contains('lay')|TeamDF['type'].str.contains('dunk') ]
RightOfTheKeythree_df_grouped_player = RightOfTheKeythree_df222.groupby('player')
made_RightOfTheKeythree_df = RightOfTheKeythree_df_grouped_player['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeythree = RightOfTheKeythree_df222.groupby('player').size().to_frame('total')
testgroupedRound = TeamDF.groupby('player')
numberOfRounds = testgroupedRound['round'].apply(lambda x: len(x.unique()))
RightOfTheKeythree_df_final222 = pd.concat([made_RightOfTheKeythree_df,totalRightOfTheKeythree,numberOfRounds],axis='columns').reset_index()
RightOfTheKeythree_df_final222['Percentage'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['total']*100
RightOfTheKeythree_df_final222['madeperround'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['round']
RightOfTheKeythree_df_final222.sort_values(by='madeperround', ascending=False, inplace=True)

RightOfTheKeythree_df_final222.head(20)
# Out:
# Empty DataFrame
# Columns: [player, made, total, round, Percentage, madeperround]
# Index: []

# %%
laydunk_df = TeamDF.loc[TeamDF['type'].str.contains('lay')|TeamDF['type'].str.contains('dunk') ]
laydunk_df_grouped_player = laydunk_df.groupby('player')
made_laydunk_df = laydunk_df_grouped_player['made'].apply(lambda x: x.str.contains('made').sum())
totaldunklay = laydunk_df.groupby('player').size().to_frame('total')
testgroupedRound_laydunk = TeamDF.groupby('player')
numberOfRounds_dunk_lay = testgroupedRound_laydunk['round'].apply(lambda x: len(x.unique()))
dunklay_df_final222 = pd.concat([made_laydunk_df,totaldunklay,numberOfRounds_dunk_lay],axis='columns').reset_index()
dunklay_df_final222['Percentage'] = dunklay_df_final222['made']/dunklay_df_final222['total']*100
dunklay_df_final222['madeperround'] = dunklay_df_final222['made']/dunklay_df_final222['round']
dunklay_df_final222.sort_values(by='madeperround', ascending=False, inplace=True)

dunklay_df_final222.head(20)
# Out:
#             player  made  total  round  Percentage  madeperround
# 6       D. Stanley   8.0   11.0      1   72.727273           8.0
# 9      J. Makhlouf   6.0   12.0      1   50.000000           6.0
# 7         I. Ahmad   3.0    5.0      1   60.000000           3.0
# 10     M. Martinez   3.0    4.0      1   75.000000           3.0
# 0         A. Majok   2.0    4.0      1   50.000000           2.0
# 2       A. Peacock   2.0    6.0      1   33.333333           2.0
# 12     Y. Ghantous   2.0    4.0      1   50.000000           2.0
# 1       A. Mansour   1.0    1.0      1  100.000000           1.0
# 5        C. Khalil   1.0    1.0      1  100.000000           1.0
# 8    J. Abi Kheres   1.0    1.0      1  100.000000           1.0
# 11       N. Dhainy   1.0    2.0      1   50.000000           1.0
# 3         A. Saoud   0.0    2.0      1    0.000000           0.0
# 4       B. Tabbara   0.0    2.0      1    0.000000           0.0
# ...

# %%
RightOfTheKeythree_df_final222['Percentage'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['total']*100
RightOfTheKeythree_df_final222['Percentage'] = RightOfTheKeythree_df_final222['made']/RightOfTheKeythree_df_final222['total']*100

# %%
##teams
RightOfTheKeythree_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Right of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


RightOfTheKeythree_grouped_teams = RightOfTheKeythree_df_teams.groupby('team')
madeRightOfTheKeythree = RightOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeyThree = RightOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightOfTheKeythree_final_teams = pd.concat([madeRightOfTheKeythree,totalRightOfTheKeyThree],axis ='columns').reset_index()
RightOfTheKeythree_final_teams['Percentage'] = RightOfTheKeythree_final_teams['made']/RightOfTheKeythree_final_teams['total']*100
RightOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightOfTheKeythree_final_teams.head(20).to_csv('processed/teams/RightOfTheKeythree_final_teams.csv')

LeftOfTheKeythree_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Left of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftOfTheKeythree_grouped_teams = LeftOfTheKeythree_df_teams.groupby('team')
madeLeftOfTheKeythree = LeftOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftOfTheKeyThree = LeftOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftOfTheKeythree_final_teams = pd.concat([madeLeftOfTheKeythree,totalLeftOfTheKeyThree],axis ='columns').reset_index()
LeftOfTheKeythree_final_teams['Percentage'] = LeftOfTheKeythree_final_teams['made']/LeftOfTheKeythree_final_teams['total']*100
LeftOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftOfTheKeythree_final_teams.head(20).to_csv('processed/teams/LeftOfTheKeythree_final_teams.csv')

 
TopOfTheKeythree_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Top of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


TopOfTheKeythree_grouped_teams = TopOfTheKeythree_df_teams.groupby('team')
madeTopOfTheKeythree = TopOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopOfTheKeyThree = TopOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

TopOfTheKeythree_final_teams = pd.concat([madeTopOfTheKeythree,totalTopOfTheKeyThree],axis ='columns').reset_index()
TopOfTheKeythree_final_teams['Percentage'] = TopOfTheKeythree_final_teams['made']/TopOfTheKeythree_final_teams['total']*100
TopOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopOfTheKeythree_final_teams.head(20).to_csv('processed/teams/TopOfTheKeythree_final_teams.csv')



RightCornerthree_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Right Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()
RightCornerthree_grouped_teams = RightCornerthree_df_teams.groupby('team')
madeRightCornerthree = RightCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightCornerThree = RightCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
RightCornerthree_final_teams = pd.concat([madeRightCornerthree,totalRightCornerThree],axis ='columns').reset_index()
RightCornerthree_final_teams['Percentage'] = RightCornerthree_final_teams['made']/RightCornerthree_final_teams['total']*100
RightCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightCornerthree_final_teams.head(20).to_csv('processed/teams/RightCornerTeams.csv')


 
LeftCornerthree_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Left Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftCornerthree_grouped_teams = LeftCornerthree_df_teams.groupby('team')
madeLeftCornerthree = LeftCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftCornerThree = LeftCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftCornerthree_final_teams = pd.concat([madeLeftCornerthree,totalLeftCornerThree],axis ='columns').reset_index()
LeftCornerthree_final_teams['Percentage'] = LeftCornerthree_final_teams['made']/LeftCornerthree_final_teams['total']*100
LeftCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftCornerthree_final_teams.head(20).to_csv('processed/teams/LeftCorner.csv')



 
Restricted_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()


Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20).to_csv('processed/teams/Restricted.csv')



 
Restricted_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()
Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20)




 
InsideThePaint_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Inside the paint')]
#RightOfTheKeythree['team'].value_counts()


InsideThePaint_grouped_teams = InsideThePaint_df_teams.groupby('team')
madeInsideThePaint = InsideThePaint_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalInsideThePaint = InsideThePaint_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

InsideThePaint_final_teams = pd.concat([madeInsideThePaint,totalInsideThePaint],axis ='columns').reset_index()
InsideThePaint_final_teams['Percentage'] = InsideThePaint_final_teams['made']/InsideThePaint_final_teams['total']*100
InsideThePaint_final_teams.sort_values(by='made', ascending=False, inplace=True)
InsideThePaint_final_teams.head(20).to_csv('processed/teams/InsidethePaint.csv')




 
RightMidrange_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Right midrange')]
#RightOfTheKeythree['team'].value_counts()


RightMidrange_grouped_teams = RightMidrange_df_teams.groupby('team')
madeRightMidrange = RightMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightMidrange = RightMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightMidrange_final_teams = pd.concat([madeRightMidrange,totalRightMidrange],axis ='columns').reset_index()
RightMidrange_final_teams['Percentage'] = RightMidrange_final_teams['made']/RightMidrange_final_teams['total']*100
RightMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightMidrange_final_teams.head(20).to_csv('processed/teams/RightMidTeam.csv')


 
LeftMidrange_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Left midrange')]
#RightOfTheKeythree['team'].value_counts()


LeftMidrange_grouped_teams = LeftMidrange_df_teams.groupby('team')
madeLeftMidrange = LeftMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftMidrange = LeftMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftMidrange_final_teams = pd.concat([madeLeftMidrange,totalLeftMidrange],axis ='columns').reset_index()
LeftMidrange_final_teams['Percentage'] = LeftMidrange_final_teams['made']/LeftMidrange_final_teams['total']*100
LeftMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftMidrange_final_teams.head(20).to_csv('processed/teams/LeftMidrangeTeam.csv')




TopMidrange_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Top of the midrange')]
#RightOfTheKeythree['team'].value_counts()
TopMidrange_grouped_teams = TopMidrange_df_teams.groupby('team')
madeTopMidrange = TopMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopMidrange = TopMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
TopMidrange_final_teams = pd.concat([madeTopMidrange,totalTopMidrange],axis ='columns').reset_index()
TopMidrange_final_teams['Percentage'] = TopMidrange_final_teams['made']/TopMidrange_final_teams['total']*100
TopMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopMidrange_final_teams.head(20).to_csv('processed/teams/TopMidrange.csv')

LeftCornerthree_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 11     Sagesse    10     24   41.666667
# 1        Atlas     8     24   33.333333
# 8      Mariste     7     17   41.176471
# 0     Antranik     5     11   45.454545
# 9          NSA     4      8   50.000000
# 10      Riyadi     4      9   44.444444
# 3       Byblos     3      9   33.333333
# 4       Dynamo     3      8   37.500000
# 5   Homenetmen     2      9   22.222222
# 6        Hoops     2      7   28.571429
# 7      Leaders     2      5   40.000000
# 2       Beirut     0      5    0.000000

# %%
byZoneRetrieve('Gyok')
# Out:
# C:\Users\Jad\AppData\Local\Temp\ipykernel_32944\1723096166.py:63: RuntimeWarning: invalid value encountered in longlong_scalars
#   perc = madeTopMidrange_player/totalTopMidrange_player*100
# {'rightofthekeythree_dic': {'made': 4, 'total': 12, 'perc': 33.33333333333333},
#  'TopOfTheKeythree_dic': {'made': 6, 'total': 10, 'perc': 60.0},
#  'leftofthekeythree_dic': {'made': 6, 'total': 10, 'perc': 60.0},
#  'RightCornerThree_dic': {'made': 1, 'total': 1, 'perc': 100.0},
#  'LeftCornerThree_dic': {'made': 1, 'total': 1, 'perc': 100.0},
#  'Insidethepaint_dic': {'made': 2, 'total': 3, 'perc': 66.66666666666666},
#  'Restricted': {'made': 13, 'total': 21, 'perc': 61.904761904761905},
#  'RightMidrange': {'made': 1, 'total': 4, 'perc': 25.0},
#  'TopMidrange_dic': {'made': 0, 'total': 0, 'perc': nan},
#  'LeftMidrange_dic': {'made': 0, 'total': 2, 'perc': 0.0}}

# %%
TeamDF.loc[TeamDF['player'].str.contains('Gyok')&TeamDF['zone'].str.contains('Right Corner')]
# Out:
#               player    team oponent        left     bottom  made  type  \
# 8188   H. Gyokochian  Riyadi  nobig4  706.799998  75.446998  made  step
#
#      distance Home/Away              zone round
# 8188      3pt      Away  Right Corner 3pt     2

# %%
##creating a function for players and best players in teams 

def byZoneRetrieve(playerDF):
    #playerDF = TeamDF.loc[TeamDF['player'].str.contains(player)]
    
    RightOfTheKeythree_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Right of the key 3pt')]
    madeRightOfTheKeythree_player = RightOfTheKeythree_df_player_func['made'].str.contains('made').sum()
    totalRightOfTheKeyThree_player = len(RightOfTheKeythree_df_player_func)
    perc = madeRightOfTheKeythree_player/totalRightOfTheKeyThree_player*100
    rightofthekeythree_dic = {'made':madeRightOfTheKeythree_player,'total':totalRightOfTheKeyThree_player,'perc':perc}
    ######################################################################
    LeftOfTheKeythree_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Left of the key 3pt')]
    totalLeftOfTheKeyThree_player = len(LeftOfTheKeythree_df_player_func)
    madeLeftOfTheKeythree_player = LeftOfTheKeythree_df_player_func['made'].str.contains('made').sum()
    perc = madeLeftOfTheKeythree_player/totalLeftOfTheKeyThree_player*100
    leftofthekeythree_dic = {'made':madeLeftOfTheKeythree_player,'total':totalLeftOfTheKeyThree_player,'perc':perc}
    #################################################################################################
    TopOfTheKeythree_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Top of the key 3pt')]
    totalTopOfTheKeyThree_player = len(TopOfTheKeythree_df_player_func)
    madeTopOfTheKeythree_player = TopOfTheKeythree_df_player_func['made'].str.contains('made').sum()
    perc = madeTopOfTheKeythree_player/totalTopOfTheKeyThree_player*100
    TopOfTheKeythree_dic = {'made':madeTopOfTheKeythree_player,'total':totalTopOfTheKeyThree_player,'perc':perc}
    #################################################################################################
    RightCornerThree_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Right Corner 3pt')]
    totalRightCornerThree_player = len(RightCornerThree_df_player_func)
    madeRightCornerThree_player = RightCornerThree_df_player_func['made'].str.contains('made').sum()
    perc = madeRightCornerThree_player/totalRightCornerThree_player*100
    RightCornerThree_dic = {'made':madeRightCornerThree_player,'total':totalRightCornerThree_player,'perc':perc}
    #################################################################################################
    LeftCornerThree_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Left Corner 3pt')]
    totalLeftCornerThree_player = len(LeftCornerThree_df_player_func)
    madeLeftCornerThree_player = LeftCornerThree_df_player_func['made'].str.contains('made').sum()
    perc = madeLeftCornerThree_player/totalLeftCornerThree_player*100
    LeftCornerThree_dic = {'made':madeLeftCornerThree_player,'total':totalLeftCornerThree_player,'perc':perc}
    ##################################################################################################
    Insidethepaint_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Inside the paint')]
    totalInsidethepaint_player = len(Insidethepaint_df_player_func)
    madeInsidethepaint_player = Insidethepaint_df_player_func['made'].str.contains('made').sum()
    perc = madeInsidethepaint_player/totalInsidethepaint_player*100
    Insidethepaint_dic = {'made':madeInsidethepaint_player,'total':totalInsidethepaint_player,'perc':perc}
    ##################################################################################################
    restrictedarea_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Restricted')]
    totalrestrictedarea_player = len(restrictedarea_df_player_func)
    maderestrictedarea_player = restrictedarea_df_player_func['made'].str.contains('made').sum()
    perc = maderestrictedarea_player/totalrestrictedarea_player*100
    restrictedarea_dic = {'made':maderestrictedarea_player,'total':totalrestrictedarea_player,'perc':perc}
    ####################################################################################################
    RightMidrange_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Right midrange')]
    totalRightMidrange_player = len(RightMidrange_df_player_func)
    madeRightMidrange_player = RightMidrange_df_player_func['made'].str.contains('made').sum()
    perc = madeRightMidrange_player/totalRightMidrange_player*100
    RightMidrange_dic = {'made':madeRightMidrange_player,'total':totalRightMidrange_player,'perc':perc}
    ####################################################################################################
    LeftMidrange_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Left midrange')]
    totalLeftMidrange_player = len(LeftMidrange_df_player_func)
    madeLeftMidrange_player = LeftMidrange_df_player_func['made'].str.contains('made').sum()
    perc = madeLeftMidrange_player/totalLeftMidrange_player*100
    LeftMidrange_dic = {'made':madeLeftMidrange_player,'total':totalLeftMidrange_player,'perc':perc}
    ####################################################################################################
    TopMidrange_df_player_func = playerDF.loc[playerDF['zone'].str.contains('Top of the midrange')]
    totalTopMidrange_player = len(TopMidrange_df_player_func)
    madeTopMidrange_player = TopMidrange_df_player_func['made'].str.contains('made').sum()
    perc = madeTopMidrange_player/totalTopMidrange_player*100
    TopMidrange_dic = {'made':madeTopMidrange_player,'total':totalTopMidrange_player,'perc':perc}
    
    
    
    retDic = {"rightofthekeythree_dic":rightofthekeythree_dic,"TopOfTheKeythree_dic":TopOfTheKeythree_dic,
              "leftofthekeythree_dic":leftofthekeythree_dic,"RightCornerThree_dic":RightCornerThree_dic,
             "LeftCornerThree_dic":LeftCornerThree_dic,"Insidethepaint_dic":Insidethepaint_dic,
             "Restricted":restrictedarea_dic,"RightMidrange":RightMidrange_dic,"TopMidrange_dic":TopMidrange_dic
             ,"LeftMidrange_dic":LeftMidrange_dic}
    
    return retDic

# %%
# Out:
# {'made': 3, 'total': 7, 'perc': 42.857142857142854}

# %%
byZoneRetrieve('J. Jackson')
# Out:
# {'rightofthekeythree_dic': {'made': 4, 'total': 17, 'perc': 23.52941176470588},
#  'TopOfTheKeythree_dic': {'made': 2, 'total': 3, 'perc': 66.66666666666666},
#  'leftofthekeythree_dic': {'made': 1, 'total': 11, 'perc': 9.090909090909092},
#  'RightCornerThree_dic': {'made': 0, 'total': 2, 'perc': 0.0},
#  'LeftCornerThree_dic': {'made': 1, 'total': 1, 'perc': 100.0},
#  'Insidethepaint_dic': {'made': 8, 'total': 17, 'perc': 47.05882352941176},
#  'Restricted': {'made': 40, 'total': 53, 'perc': 75.47169811320755},
#  'RightMidrange': {'made': 3, 'total': 11, 'perc': 27.27272727272727},
#  'TopMidrange_dic': {'made': 1, 'total': 2, 'perc': 50.0},
#  'LeftMidrange_dic': {'made': 3, 'total': 9, 'perc': 33.33333333333333}}

# %%
#### defending the lines 

##teams
RightOfTheKeythree_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Right of the key 3pt')]
#RightOfTheKeythree['oponent'].value_counts()
RightOfTheKeythree_grouped_oponentteams = RightOfTheKeythree_df_oponentteams.groupby('oponent')
madeRightOfTheKeythree = RightOfTheKeythree_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeyThree = RightOfTheKeythree_df_oponentteams.groupby('oponent').size().to_frame('total')
RightOfTheKeythree_final_oponentteams = pd.concat([madeRightOfTheKeythree,totalRightOfTheKeyThree],axis ='columns').reset_index()
RightOfTheKeythree_final_oponentteams['Percentage'] = RightOfTheKeythree_final_oponentteams['made']/RightOfTheKeythree_final_oponentteams['total']*100
RightOfTheKeythree_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
RightOfTheKeythree_final_oponentteams.head(20)

LeftOfTheKeythree_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Left of the key 3pt')]
#RightOfTheKeythree['oponent'].value_counts()


LeftOfTheKeythree_grouped_oponentteams = LeftOfTheKeythree_df_oponentteams.groupby('oponent')
madeLeftOfTheKeythree = LeftOfTheKeythree_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftOfTheKeyThree = LeftOfTheKeythree_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters

LeftOfTheKeythree_final_oponentteams = pd.concat([madeLeftOfTheKeythree,totalLeftOfTheKeyThree],axis ='columns').reset_index()
LeftOfTheKeythree_final_oponentteams['Percentage'] = LeftOfTheKeythree_final_oponentteams['made']/LeftOfTheKeythree_final_oponentteams['total']*100
LeftOfTheKeythree_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
LeftOfTheKeythree_final_oponentteams.head(20)

 
TopOfTheKeythree_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Top of the key 3pt')]
#RightOfTheKeythree['oponent'].value_counts()


TopOfTheKeythree_grouped_oponentteams = TopOfTheKeythree_df_oponentteams.groupby('oponent')
madeTopOfTheKeythree = TopOfTheKeythree_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopOfTheKeyThree = TopOfTheKeythree_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters

TopOfTheKeythree_final_oponentteams = pd.concat([madeTopOfTheKeythree,totalTopOfTheKeyThree],axis ='columns').reset_index()
TopOfTheKeythree_final_oponentteams['Percentage'] = TopOfTheKeythree_final_oponentteams['made']/TopOfTheKeythree_final_oponentteams['total']*100
TopOfTheKeythree_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
TopOfTheKeythree_final_oponentteams.head(20)



RightCornerthree_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Right Corner 3pt')]
#RightOfTheKeythree['oponent'].value_counts()
RightCornerthree_grouped_oponentteams = RightCornerthree_df_oponentteams.groupby('oponent')
madeRightCornerthree = RightCornerthree_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightCornerThree = RightCornerthree_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters
RightCornerthree_final_oponentteams = pd.concat([madeRightCornerthree,totalRightCornerThree],axis ='columns').reset_index()
RightCornerthree_final_oponentteams['Percentage'] = RightCornerthree_final_oponentteams['made']/RightCornerthree_final_oponentteams['total']*100
RightCornerthree_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
RightCornerthree_final_oponentteams.head(20)


 
LeftCornerthree_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Left Corner 3pt')]
#RightOfTheKeythree['oponent'].value_counts()


LeftCornerthree_grouped_oponentteams = LeftCornerthree_df_oponentteams.groupby('oponent')
madeLeftCornerthree = LeftCornerthree_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftCornerThree = LeftCornerthree_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters

LeftCornerthree_final_oponentteams = pd.concat([madeLeftCornerthree,totalLeftCornerThree],axis ='columns').reset_index()
LeftCornerthree_final_oponentteams['Percentage'] = LeftCornerthree_final_oponentteams['made']/LeftCornerthree_final_oponentteams['total']*100
LeftCornerthree_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
LeftCornerthree_final_oponentteams.head(20)



 
Restricted_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['oponent'].value_counts()


Restricted_grouped_oponentteams = Restricted_df_oponentteams.groupby('oponent')
madeRestricted = Restricted_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters

Restricted_final_oponentteams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_oponentteams['Percentage'] = Restricted_final_oponentteams['made']/Restricted_final_oponentteams['total']*100
Restricted_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_oponentteams.head(20)



 
Restricted_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['oponent'].value_counts()
Restricted_grouped_oponentteams = Restricted_df_oponentteams.groupby('oponent')
madeRestricted = Restricted_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters
Restricted_final_oponentteams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_oponentteams['Percentage'] = Restricted_final_oponentteams['made']/Restricted_final_oponentteams['total']*100
Restricted_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_oponentteams.head(20)




 
InsideThePaint_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Inside the paint')]
#RightOfTheKeythree['oponent'].value_counts()


InsideThePaint_grouped_oponentteams = InsideThePaint_df_oponentteams.groupby('oponent')
madeInsideThePaint = InsideThePaint_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalInsideThePaint = InsideThePaint_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters

InsideThePaint_final_oponentteams = pd.concat([madeInsideThePaint,totalInsideThePaint],axis ='columns').reset_index()
InsideThePaint_final_oponentteams['Percentage'] = InsideThePaint_final_oponentteams['made']/InsideThePaint_final_oponentteams['total']*100
InsideThePaint_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
InsideThePaint_final_oponentteams.head(20)




 
RightMidrange_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Right midrange')]
#RightOfTheKeythree['oponent'].value_counts()


RightMidrange_grouped_oponentteams = RightMidrange_df_oponentteams.groupby('oponent')
madeRightMidrange = RightMidrange_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightMidrange = RightMidrange_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters

RightMidrange_final_oponentteams = pd.concat([madeRightMidrange,totalRightMidrange],axis ='columns').reset_index()
RightMidrange_final_oponentteams['Percentage'] = RightMidrange_final_oponentteams['made']/RightMidrange_final_oponentteams['total']*100
RightMidrange_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
RightMidrange_final_oponentteams.head(20)


 
LeftMidrange_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Left midrange')]
#RightOfTheKeythree['oponent'].value_counts()


LeftMidrange_grouped_oponentteams = LeftMidrange_df_oponentteams.groupby('oponent')
madeLeftMidrange = LeftMidrange_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftMidrange = LeftMidrange_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters

LeftMidrange_final_oponentteams = pd.concat([madeLeftMidrange,totalLeftMidrange],axis ='columns').reset_index()
LeftMidrange_final_oponentteams['Percentage'] = LeftMidrange_final_oponentteams['made']/LeftMidrange_final_oponentteams['total']*100
LeftMidrange_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
LeftMidrange_final_oponentteams.head(20)




TopMidrange_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Top of the midrange')]
#RightOfTheKeythree['oponent'].value_counts()
TopMidrange_grouped_oponentteams = TopMidrange_df_oponentteams.groupby('oponent')
madeTopMidrange = TopMidrange_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopMidrange = TopMidrange_df_oponentteams.groupby('oponent').size().to_frame('total')
#totalfloaters
TopMidrange_final_oponentteams = pd.concat([madeTopMidrange,totalTopMidrange],axis ='columns').reset_index()
TopMidrange_final_oponentteams['Percentage'] = TopMidrange_final_oponentteams['made']/TopMidrange_final_oponentteams['total']*100
TopMidrange_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)


LeftOfTheKeythree_final_oponentteams.head(20)
# Out:
#    oponent  made  total  Percentage
# 2   nobig4   155    531   29.190207
# 0   beirut    25     86   29.069767
# 3   riyadi    17     62   27.419355
# 4  sagesse    15     63   23.809524
# 1   dynamo    13     69   18.840580

# %%
RightOfTheKeythree_df_oponentteams = TeamDF.loc[TeamDF['zone'].str.contains('Right of the key 3pt')]
#RightOfTheKeythree['oponent'].value_counts()
RightOfTheKeythree_grouped_oponentteams = RightOfTheKeythree_df_oponentteams.groupby('oponent')
madeRightOfTheKeythree = RightOfTheKeythree_grouped_oponentteams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeyThree = RightOfTheKeythree_df_oponentteams.groupby('oponent').size().to_frame('total')
RightOfTheKeythree_final_oponentteams = pd.concat([madeRightOfTheKeythree,totalRightOfTheKeyThree],axis ='columns').reset_index()
RightOfTheKeythree_final_oponentteams['Percentage'] = RightOfTheKeythree_final_oponentteams['made']/RightOfTheKeythree_final_oponentteams['total']*100
RightOfTheKeythree_final_oponentteams.sort_values(by='made', ascending=False, inplace=True)
RightOfTheKeythree_final_oponentteams.head(20)
# Out:
#    oponent  made  total  Percentage
# 2   nobig4   102    349   29.226361
# 4  sagesse    23     61   37.704918
# 0   beirut    19     67   28.358209
# 1   dynamo    17     46   36.956522
# 3   riyadi    12     40   30.000000

# %%
riy = TeamDF.loc[TeamDF['team'].str.contains('Sagesse')]
riy['player'].unique()
# Out:
# array([' K. Rush', ' A. Mezher', ' C. Alexander', ' M. Khoueiry',
#        ' P. Bou Abboud', ' S. Darwich', ' J. Jarrouge',
#        ' A. Abdel Massih', ' R. Akl', ' E. Sebaaly', ' R. Moussa',
#        ' M. Ziadeh'], dtype=object)

# %%
Beirut_df = TeamDF.loc[TeamDF['team'].str.contains('Beirut')&TeamDF['made'].str.contains('made')]
Beirut_df['zone'].value_counts()
# Out:
# Restricted Area         144
# Inside the paint         35
# Right of the key 3pt     30
# Left of the key 3pt      24
# Top of the key 3pt       21
# Left midrange 2pt        21
# Right midrange            8
# Top of the midrange       5
# Left Corner 3pt           5
# Right Corner 3pt          4
# Name: zone, dtype: int64

# %%
RightMidrange_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 5   Homenetmen    14     41   34.146341
# 9          NSA    14     41   34.146341
# 7      Leaders    11     30   36.666667
# 1        Atlas     9     33   27.272727
# 0     Antranik     8     23   34.782609
# 2       Beirut     7     18   38.888889
# 3       Byblos     5     21   23.809524
# 4       Dynamo     5     19   26.315789
# 10      Riyadi     5     19   26.315789
# 11     Sagesse     5     17   29.411765
# 6        Hoops     2     16   12.500000
# 8      Mariste     0      9    0.000000

# %%
LeftMidrange_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 2       Beirut    19     35   54.285714
# 1        Atlas    15     39   38.461538
# 9          NSA    14     31   45.161290
# 11     Sagesse    13     27   48.148148
# 5   Homenetmen    11     35   31.428571
# 6        Hoops     9     23   39.130435
# 7      Leaders     8     27   29.629630
# 4       Dynamo     7     19   36.842105
# 10      Riyadi     7     24   29.166667
# 0     Antranik     4     19   21.052632
# 3       Byblos     2     15   13.333333
# 8      Mariste     2     10   20.000000

# %%
InsideThePaint_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 9          NSA    40     94   42.553191
# 2       Beirut    31     65   47.692308
# 5   Homenetmen    29     96   30.208333
# 7      Leaders    29     78   37.179487
# 6        Hoops    25     69   36.231884
# 1        Atlas    21     80   26.250000
# 3       Byblos    21     61   34.426230
# 10      Riyadi    20     56   35.714286
# 4       Dynamo    19     63   30.158730
# 11     Sagesse    17     46   36.956522
# 0     Antranik    14     40   35.000000
# 8      Mariste    12     67   17.910448

# %%
Restricted_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 11     Sagesse   183    280   65.357143
# 4       Dynamo   175    276   63.405797
# 10      Riyadi   141    198   71.212121
# 8      Mariste   135    230   58.695652
# 2       Beirut   128    200   64.000000
# 9          NSA   126    235   53.617021
# 0     Antranik   122    203   60.098522
# 5   Homenetmen   101    180   56.111111
# 1        Atlas    99    186   53.225806
# 6        Hoops    94    185   50.810811
# 7      Leaders    82    157   52.229299
# 3       Byblos    77    134   57.462687

# %%
LeftCornerthree_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 11     Sagesse     6     17   35.294118
# 2       Beirut     5      7   71.428571
# 3       Byblos     5      7   71.428571
# 8      Mariste     5     12   41.666667
# 1        Atlas     4     18   22.222222
# 10      Riyadi     4      8   50.000000
# 0     Antranik     3     10   30.000000
# 4       Dynamo     3      5   60.000000
# 5   Homenetmen     3     11   27.272727
# 7      Leaders     2      4   50.000000
# 9          NSA     2      9   22.222222
# 6        Hoops     0     10    0.000000

# %%
RightCornerthree_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 11     Sagesse     9     15   60.000000
# 5   Homenetmen     6     11   54.545455
# 10      Riyadi     6     14   42.857143
# 0     Antranik     5     16   31.250000
# 7      Leaders     5     17   29.411765
# 1        Atlas     4     13   30.769231
# 6        Hoops     4      8   50.000000
# 9          NSA     4     14   28.571429
# 2       Beirut     3     12   25.000000
# 4       Dynamo     2      7   28.571429
# 8      Mariste     2      8   25.000000
# 3       Byblos     1      6   16.666667

# %%
TopOfTheKeythree_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 6        Hoops    22     60   36.666667
# 2       Beirut    19     44   43.181818
# 5   Homenetmen    18     44   40.909091
# 8      Mariste    18     63   28.571429
# 10      Riyadi    15     41   36.585366
# 4       Dynamo    14     38   36.842105
# 1        Atlas    13     44   29.545455
# 11     Sagesse    13     34   38.235294
# 0     Antranik     9     43   20.930233
# 9          NSA     8     27   29.629630
# 3       Byblos     4     15   26.666667
# 7      Leaders     4     22   18.181818

# %%
LeftOfTheKeythree_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 6        Hoops    23     68   33.823529
# 2       Beirut    21     55   38.181818
# 4       Dynamo    19     65   29.230769
# 10      Riyadi    18     53   33.962264
# 3       Byblos    17     51   33.333333
# 7      Leaders    13     49   26.530612
# 0     Antranik    12     46   26.086957
# 1        Atlas    12     74   16.216216
# 8      Mariste    12     39   30.769231
# 11     Sagesse    11     38   28.947368
# 5   Homenetmen     9     24   37.500000
# 9          NSA     9     41   21.951220

# %%
twojumpshots_df = TeamDF.loc[TeamDF['type'].str.contains('jump')&TeamDF['distance'].str.contains("2")]
threejumpshots_df = TeamDF.loc[TeamDF['type'].str.contains('jump')&TeamDF['distance'].str.contains("3")]


twojumpshots_grouped = twojumpshots_df.groupby('player')
threejumpshots_grouped = threejumpshots_df.groupby('player')

madetwojumpers = twojumpshots_grouped['made'].apply(lambda x: x.str.contains('made').sum())
madethreejumpers = threejumpshots_grouped['made'].apply(lambda x: x.str.contains('made').sum())

madetwojumpers.rename('MadeTwos',inplace=True)
madethreejumpers.rename('MadeThrees',inplace=True)



totaltwojumpers = twojumpshots_df.groupby('player').size().to_frame('totaltwo')
totalthreejumpers = threejumpshots_df.groupby('player').size().to_frame('totalthree')


two_concated = pd.concat([madetwojumpers,totaltwojumpers,madethreejumpers,totalthreejumpers],axis ='columns').reset_index()

two_concated['TotalJumpshots'] = two_concated['totaltwo']+two_concated['totalthree']
two_concated['eFG'] = (two_concated['MadeTwos']+1.5*two_concated['MadeThrees'])/two_concated['TotalJumpshots']*100


test = two_concated.head(30)


two_concated["TotalJumpshots"] = pd.to_numeric(two_concated["TotalJumpshots"])
two_concated["eFG"] = pd.to_numeric(two_concated["eFG"])
two_concated.sort_values(by='eFG', ascending=False, inplace=True)
JS_df = two_concated.loc[two_concated['TotalJumpshots']>40]
JS_df.head(40)
# Out:
#              player  MadeTwos  totaltwo  MadeThrees  totalthree  \
# 103        M. Dixon      13.0      20.0        16.0        31.0
# 57    H. Gyokochian       3.0       8.0        17.0        34.0
# 86        K. Horton      13.0      27.0        17.0        35.0
# 14        A. Mezher       4.0      12.0        14.0        30.0
# 84        K. Feagin       2.0       5.0        15.0        37.0
# 99      M. Al Malla       3.0       9.0        28.0        70.0
# 129   P. Bou Abboud      11.0      19.0        10.0        27.0
# 166       Z. Lofton       7.0      21.0        35.0        89.0
# 136          R. Akl       4.0      12.0        15.0        37.0
# 62        I. Thomas      11.0      28.0        15.0        34.0
# 130       P. Fakhry       1.0       5.0        17.0        46.0
# 104       M. Haddad       7.0      16.0        23.0        64.0
# 24     C. Alexander      11.0      34.0        10.0        17.0
# 79     J. Willliams       7.0      26.0        26.0        65.0
# ...

# %%
HGyo = TeamDF.loc[TeamDF['player'].str.contains('Mezher')&TeamDF['type'].str.contains('jump')]
regular_plot(HGyo)

# %%
import plotly.express as px
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
fig = px.scatter(two_concated.head(30), x="TotalJumpshots", y="eFG",text="player"
	         ,log_x=True, size_max=60)
fig.show()
# Out:
# <div>                            <div id="9026ece9-3d6e-4c6a-80f0-63e80b7ad3dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9026ece9-3d6e-4c6a-80f0-63e80b7ad3dc")) {                    Plotly.newPlot(                        "9026ece9-3d6e-4c6a-80f0-63e80b7ad3dc",                        [{"hovertemplate":"TotalJumpshots=%{x}<br>eFG=%{y}<br>player=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":[" Z. Lofton"," J. Dwayn"," A. Ibrahim"," M. Haddad"," Y. Ghantous"," A. Fairely"," J. Salem"," G. Daaboul"," J. Jones"," M. Al Malla"," A. Sabbagh"," M. Dixon"," K. Aoun"," W. Sidney"," H. Gyokochian"," A. Haidar"," K. Feagin"," M. Carter"," 
# ...

# %%
two_concated.to_csv('blabla.csv')

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

plt.scatter(x=test['TotalJumpshots'],
           y=test['eFG'],
           s=test['TotalJumpshots'],
           alpha=0.5,
           c="Red")

# %%
fig = px.scatter(two_concated.head(19), x='TotalJumpshots', y='eFG', text="player", log_x=True, size_max=60)

fig.update_traces(textposition='top center')

fig.update_layout(
    height=800,
    title_text='Top 20 Total Jump Shots')
fig.update_traces(textposition=improve_text_position(two_concated.head(19)['TotalJumpshots']))
fig.show()
# Out:
# <div>                            <div id="5ff9ca1a-6900-48c3-b0db-89e2325621fd" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ff9ca1a-6900-48c3-b0db-89e2325621fd")) {                    Plotly.newPlot(                        "5ff9ca1a-6900-48c3-b0db-89e2325621fd",                        [{"hovertemplate":"TotalJumpshots=%{x}<br>eFG=%{y}<br>player=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","orientation":"v","showlegend":false,"text":[" Z. Lofton"," J. Dwayn"," A. Ibrahim"," M. Haddad"," Y. Ghantous"," A. Fairely"," J. Salem"," G. Daaboul"," J. Jones"," M. Al Malla"," A. Sabbagh"," M. Dixon"," K. Aoun"," W. Sidney"," H. Gyokochian"," A. Haidar"," K. Feagin"," M. Carter"," 
# ...

# %%
def improve_text_position(x):
    """ it is more efficient if the x values are sorted """
    positions = ['top center', 'bottom center']  # you can add more: left center ...
    return [positions[i % len(positions)] for i in range(len(x))]

# %%
TeamDF
# Out:
#               player        team  oponent        left      bottom    made  \
# 0      D. Baghdadian  Homenetmen   dynamo  249.150009   75.446998  missed
# 1           J. Jones  Homenetmen   dynamo  151.650009  -13.604995  missed
# 2           J. Dwayn  Homenetmen   dynamo  -68.700027  223.685999  missed
# 3           J. Jones  Homenetmen   dynamo  -30.449982   24.676501    made
# 4           J. Dwayn  Homenetmen   dynamo -157.649975  100.968012  missed
# ...              ...         ...      ...         ...         ...     ...
# 5746      C. Yazbeck      Byblos  sagesse   25.349979  -62.500000    made
# 5747       B. Victor      Byblos  sagesse   97.500000  380.341434    made
# 5748      A. Chidiac      Byblos  sagesse -610.200005  511.747541  missed
# 5749         G. Rizk      Byblos  sagesse  262.650032  350.748033  missed
# 5750       I. Haddad      Byblos  sagesse   42.299995  -62.500000    made
#
#           type distance Home/Away                 zone  round
# ...

# %%
haidarchart = TeamDF.loc[TeamDF['player'].str.contains('Haidar')]
haidarchart = haidar.loc[haidar['round']<7]
haidarchart['round'].value_counts()
haidarchart['zone'].value_counts()
# Out:
# Restricted Area         26
# Inside the paint        17
# Top of the key 3pt      11
# Left of the key 3pt      8
# Right of the key 3pt     4
# Right midrange           3
# Left midrange 2pt        3
# Name: zone, dtype: int64

# %%
Restricted_df = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['player'].value_counts()


Restricted_grouped = Restricted_df.groupby('player')
madeRestricted = Restricted_grouped['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df.groupby('player').size().to_frame('total')
#totalfloaters

Restricted_final = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final['Percentage'] = Restricted_final['made']/Restricted_final['total']*100
Restricted_final.sort_values(by='made', ascending=False, inplace=True)
Restricted_final.head(20)
# Out:
#              player  made  total  Percentage
# 21     C. Alexander    52     70   74.285714
# 86          K. Rush    43     56   76.785714
# 72         J. Salem    37     59   62.711864
# 105       M. Qualls    32     41   78.048780
# 95        M. Carter    32     50   64.000000
# 158       Z. Lofton    28     44   63.636364
# 5         A. Haidar    27     37   72.972973
# 56        I. Hammon    26     54   48.148148
# 57        I. Thomas    26     40   65.000000
# 64         J. Dwayn    26     40   65.000000
# 3        A. Fairely    25     44   56.818182
# 6        A. Ibrahim    24     37   64.864865
# 92    M. Abi Kheres    22     41   53.658537
# 13        A. Mezher    21     33   63.636364
# 43      G. Choueiry    20     31   64.516129
# 74     J. Willliams    20     27   74.074074
# 11         A. Majok    18     20   90.000000
# 139    S. Alaeddine    17     30   56.666667
# 68         J. Jones    16     27   59.259259
# 49        G. Souaid    16     26   61.538462

# %%
round6df=  TeamDF.loc[TeamDF['round']<7]
Restricted_df1 = round6df.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['player'].value_counts()


Restricted_grouped1 = Restricted_df1.groupby('player')
madeRestricted1 = Restricted_grouped1['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted1 = Restricted_df1.groupby('player').size().to_frame('total')
#totalfloaters

Restricted_final1 = pd.concat([madeRestricted1,totalRestricted1],axis ='columns').reset_index()
Restricted_final1['Percentage'] = Restricted_final1['made']/Restricted_final1['total']*100
Restricted_final1.sort_values(by='made', ascending=False, inplace=True)
Restricted_final1.head(20)
# Out:
#              player  made  total  Percentage
# 20     C. Alexander    42     57   73.684211
# 83          K. Rush    38     49   77.551020
# 101       M. Qualls    32     41   78.048780
# 70         J. Salem    29     50   58.000000
# 62         J. Dwayn    26     40   65.000000
# 91        M. Carter    26     41   63.414634
# 152       Z. Lofton    25     41   60.975610
# 55        I. Thomas    22     36   61.111111
# 3        A. Fairely    22     35   62.857143
# 12        A. Mezher    19     29   65.517241
# 88    M. Abi Kheres    18     34   52.941176
# 10         A. Majok    18     20   90.000000
# 54        I. Hammon    18     42   42.857143
# 72     J. Willliams    18     24   75.000000
# 41      G. Choueiry    17     27   62.962963
# 5         A. Haidar    16     26   61.538462
# 21        C. Junior    16     21   76.190476
# 47        G. Souaid    15     23   65.217391
# 50      H. El Helou    15     22   68.181818
# 66         J. Jones    15     25   60.000000

# %%
Restricted_df.loc[Restricted_df['player'].str.contains('Alexa')].head(20)
# Out:
#              player     team oponent       left      bottom    made  type  \
# 4471   C. Alexander  Sagesse  nobig4   5.100002   11.915942    made  dunk
# 4472   C. Alexander  Sagesse  nobig4  13.500023   28.749017    made   lay
# 4476   C. Alexander  Sagesse  nobig4   0.000000    5.400000  missed   lay
# 4484   C. Alexander  Sagesse  nobig4  22.050018   16.260041    made  dunk
# 4488   C. Alexander  Sagesse  nobig4 -16.049995    3.499508    made  jump
# 4498   C. Alexander  Sagesse  nobig4  43.200016   37.437008    made  dunk
# 4505   C. Alexander  Sagesse  nobig4  -9.299984  -17.677497    made  dunk
# 4512   C. Alexander  Sagesse  nobig4 -22.050018   20.332505    made  dunk
# 4514   C. Alexander  Sagesse  nobig4 -77.099991  -17.677497    made   lay
# 4523   C. Alexander  Sagesse  nobig4  58.500023  100.968012  missed   lay
# 4529   C. Alexander  Sagesse  nobig4 -17.849979   -0.844501    made  dunk
# 4532   C. Alexander  Sagesse  nobig4 -30.449982   37.436995    made  dunk
# ...

# %%
riyadibeforewael = TeamDF.loc[TeamDF['round']>=6]
Midrange_df_teams = TeamDF.loc[TeamDF['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()
Midrange_grouped_teams = Midrange_df_teams.groupby('team')
madeMidrange = Midrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalMidrange = Midrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
Midrange_final_teams = pd.concat([madeMidrange,totalMidrange],axis ='columns').reset_index()
Midrange_final_teams['Percentage'] = Midrange_final_teams['made']/Midrange_final_teams['total']*100
Midrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
Midrange_final_teams.head(20)
# Out:
#           team  made  total  Percentage
# 11     Sagesse   183    280   65.357143
# 4       Dynamo   175    276   63.405797
# 10      Riyadi   157    226   69.469027
# 8      Mariste   154    256   60.156250
# 2       Beirut   144    229   62.882096
# 9          NSA   140    265   52.830189
# 0     Antranik   133    226   58.849558
# 7      Leaders   129    226   57.079646
# 5   Homenetmen   119    211   56.398104
# 1        Atlas   116    208   55.769231
# 3       Byblos   106    169   62.721893
# 6        Hoops    99    197   50.253807

# %%
sagesseDF = TeamDF.loc[TeamDF['team'].str.contains('Sagesse')]
made_sagesseDF = sagesseDF.loc[sagesseDF['made'].str.contains('made')]
made_sagesseDF['type'].value_counts()
# Out:
# lay         116
# jump         92
# dunk         55
# driving       7
# turn          6
# floating      5
# step          3
# alley         2
# hookshot      2
# fade          1
# Name: type, dtype: int64

# %%
BeirutDF = TeamDF.loc[TeamDF['team'].str.contains('Dynamo')]
made_BeirutDF = BeirutDF.loc[BeirutDF['made'].str.contains('made')]
made_BeirutDF['type'].value_counts()
# Out:
# lay             123
# jump            106
# dunk             25
# driving          16
# layup            16
# turn              9
# floating          7
# step              5
# fade              2
# alley             2
# 1                 2
# drivinglayup      1
# floatingjump      1
# Name: type, dtype: int64

# %%
##teams
RightOfTheKeythree_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Right of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


RightOfTheKeythree_grouped_teams = RightOfTheKeythree_df_teams.groupby('team')
madeRightOfTheKeythree = RightOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeyThree = RightOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightOfTheKeythree_final_teams = pd.concat([madeRightOfTheKeythree,totalRightOfTheKeyThree],axis ='columns').reset_index()
RightOfTheKeythree_final_teams['Percentage'] = RightOfTheKeythree_final_teams['made']/RightOfTheKeythree_final_teams['total']*100
RightOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightOfTheKeythree_final_teams.head(20).to_csv('processed/teams/RightOfTheKeythree_final_teams.csv')

LeftOfTheKeythree_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Left of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftOfTheKeythree_grouped_teams = LeftOfTheKeythree_df_teams.groupby('team')
madeLeftOfTheKeythree = LeftOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftOfTheKeyThree = LeftOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftOfTheKeythree_final_teams = pd.concat([madeLeftOfTheKeythree,totalLeftOfTheKeyThree],axis ='columns').reset_index()
LeftOfTheKeythree_final_teams['Percentage'] = LeftOfTheKeythree_final_teams['made']/LeftOfTheKeythree_final_teams['total']*100
LeftOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftOfTheKeythree_final_teams.head(20).to_csv('processed/teams/LeftOfTheKeythree_final_teams.csv')

 
TopOfTheKeythree_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Top of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


TopOfTheKeythree_grouped_teams = TopOfTheKeythree_df_teams.groupby('team')
madeTopOfTheKeythree = TopOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopOfTheKeyThree = TopOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

TopOfTheKeythree_final_teams = pd.concat([madeTopOfTheKeythree,totalTopOfTheKeyThree],axis ='columns').reset_index()
TopOfTheKeythree_final_teams['Percentage'] = TopOfTheKeythree_final_teams['made']/TopOfTheKeythree_final_teams['total']*100
TopOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopOfTheKeythree_final_teams.head(20).to_csv('processed/teams/TopOfTheKeythree_final_teams.csv')



RightCornerthree_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Right Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()
RightCornerthree_grouped_teams = RightCornerthree_df_teams.groupby('team')
madeRightCornerthree = RightCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightCornerThree = RightCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
RightCornerthree_final_teams = pd.concat([madeRightCornerthree,totalRightCornerThree],axis ='columns').reset_index()
RightCornerthree_final_teams['Percentage'] = RightCornerthree_final_teams['made']/RightCornerthree_final_teams['total']*100
RightCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightCornerthree_final_teams.head(20).to_csv('processed/teams/RightCornerTeams.csv')


 
LeftCornerthree_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Left Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftCornerthree_grouped_teams = LeftCornerthree_df_teams.groupby('team')
madeLeftCornerthree = LeftCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftCornerThree = LeftCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftCornerthree_final_teams = pd.concat([madeLeftCornerthree,totalLeftCornerThree],axis ='columns').reset_index()
LeftCornerthree_final_teams['Percentage'] = LeftCornerthree_final_teams['made']/LeftCornerthree_final_teams['total']*100
LeftCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftCornerthree_final_teams.head(20).to_csv('processed/teams/LeftCorner.csv')



 
Restricted_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()


Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20).to_csv('processed/teams/Restricted.csv')



 
Restricted_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()
Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20)




 
InsideThePaint_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Inside the paint')]
#RightOfTheKeythree['team'].value_counts()


InsideThePaint_grouped_teams = InsideThePaint_df_teams.groupby('team')
madeInsideThePaint = InsideThePaint_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalInsideThePaint = InsideThePaint_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

InsideThePaint_final_teams = pd.concat([madeInsideThePaint,totalInsideThePaint],axis ='columns').reset_index()
InsideThePaint_final_teams['Percentage'] = InsideThePaint_final_teams['made']/InsideThePaint_final_teams['total']*100
InsideThePaint_final_teams.sort_values(by='made', ascending=False, inplace=True)
InsideThePaint_final_teams.head(20).to_csv('processed/teams/InsidethePaint.csv')




 
RightMidrange_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Right midrange')]
#RightOfTheKeythree['team'].value_counts()


RightMidrange_grouped_teams = RightMidrange_df_teams.groupby('team')
madeRightMidrange = RightMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightMidrange = RightMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightMidrange_final_teams = pd.concat([madeRightMidrange,totalRightMidrange],axis ='columns').reset_index()
RightMidrange_final_teams['Percentage'] = RightMidrange_final_teams['made']/RightMidrange_final_teams['total']*100
RightMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightMidrange_final_teams.head(20).to_csv('processed/teams/RightMidTeam.csv')


 
LeftMidrange_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Left midrange')]
#RightOfTheKeythree['team'].value_counts()


LeftMidrange_grouped_teams = LeftMidrange_df_teams.groupby('team')
madeLeftMidrange = LeftMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftMidrange = LeftMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftMidrange_final_teams = pd.concat([madeLeftMidrange,totalLeftMidrange],axis ='columns').reset_index()
LeftMidrange_final_teams['Percentage'] = LeftMidrange_final_teams['made']/LeftMidrange_final_teams['total']*100
LeftMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftMidrange_final_teams.head(20).to_csv('processed/teams/LeftMidrangeTeam.csv')




TopMidrange_df_teams = Criteriabig4.loc[Criteriabig4['zone'].str.contains('Top of the midrange')]
#RightOfTheKeythree['team'].value_counts()
TopMidrange_grouped_teams = TopMidrange_df_teams.groupby('team')
madeTopMidrange = TopMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopMidrange = TopMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
TopMidrange_final_teams = pd.concat([madeTopMidrange,totalTopMidrange],axis ='columns').reset_index()
TopMidrange_final_teams['Percentage'] = TopMidrange_final_teams['made']/TopMidrange_final_teams['total']*100
TopMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopMidrange_final_teams.head(20).to_csv('processed/teams/TopMidrange.csv')

TopMidrange_final_teams.head(20)
# Out:
#       team  made  total  Percentage
# 0   Beirut     1      4   25.000000
# 1   Riyadi     1      5   20.000000
# 2  Sagesse     1      3   33.333333

# %%
#Criteriabig4.loc[Criteriabig4['team'].str.contains('Dynamo') & Criteriabig4['zone'].str.contains('Restri')]['player'].value_counts()
teestttt = Criteriabig4.loc[Criteriabig4['team'].str.contains('Dynamo') & Criteriabig4['oponent'].str.contains('sagesse')]
teestttt.loc[teestttt['player'].str.contains('Ibrahim')]

byZoneRetrieve(Criteriabig4.loc[Criteriabig4['player'].str.contains('Mahmoud')])

t=Criteriabig4.loc[Criteriabig4['team'].str.contains('Dynamo') & Criteriabig4['oponent'].str.contains('sagesse')]
#byZoneRetrieve(t.loc[['player'].str.contains('Lofton')])
ttt= CriteriaNOTbig4.loc[CriteriaNOTbig4['team'].str.contains('Sagesse')]

byZoneRetrieve(ttt.loc[ttt['player'].str.contains('Mezher')])
r = Criteriabig4.loc[Criteriabig4['team'].str.contains('Sagesse')& Criteriabig4['made'].str.contains('made')]
r.loc[r['zone'].str.contains('Restricted')]['player'].value_counts()
# Out:
# C:\Users\Jad\AppData\Local\Temp\ipykernel_11164\2120361701.py:21: RuntimeWarning: invalid value encountered in longlong_scalars
#   perc = madeTopOfTheKeythree_player/totalTopOfTheKeyThree_player*100
# C:\Users\Jad\AppData\Local\Temp\ipykernel_11164\2120361701.py:33: RuntimeWarning: invalid value encountered in longlong_scalars
#   perc = madeLeftCornerThree_player/totalLeftCornerThree_player*100
# C:\Users\Jad\AppData\Local\Temp\ipykernel_11164\2120361701.py:51: RuntimeWarning: invalid value encountered in longlong_scalars
#   perc = madeRightMidrange_player/totalRightMidrange_player*100
# C:\Users\Jad\AppData\Local\Temp\ipykernel_11164\2120361701.py:57: RuntimeWarning: invalid value encountered in longlong_scalars
#   perc = madeLeftMidrange_player/totalLeftMidrange_player*100
# C:\Users\Jad\AppData\Local\Temp\ipykernel_11164\2120361701.py:63: RuntimeWarning: invalid value encountered in longlong_scalars
#   perc = madeTopMidrange_player/totalTopMidrange_player*100
# ...

# %%
##teams
RightOfTheKeythree_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Right of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


RightOfTheKeythree_grouped_teams = RightOfTheKeythree_df_teams.groupby('team')
madeRightOfTheKeythree = RightOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightOfTheKeyThree = RightOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightOfTheKeythree_final_teams = pd.concat([madeRightOfTheKeythree,totalRightOfTheKeyThree],axis ='columns').reset_index()
RightOfTheKeythree_final_teams['Percentage'] = RightOfTheKeythree_final_teams['made']/RightOfTheKeythree_final_teams['total']*100
RightOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightOfTheKeythree_final_teams.head(20).to_csv('processed/teams/RightOfTheKeythree_final_teams.csv')

LeftOfTheKeythree_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Left of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftOfTheKeythree_grouped_teams = LeftOfTheKeythree_df_teams.groupby('team')
madeLeftOfTheKeythree = LeftOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftOfTheKeyThree = LeftOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftOfTheKeythree_final_teams = pd.concat([madeLeftOfTheKeythree,totalLeftOfTheKeyThree],axis ='columns').reset_index()
LeftOfTheKeythree_final_teams['Percentage'] = LeftOfTheKeythree_final_teams['made']/LeftOfTheKeythree_final_teams['total']*100
LeftOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftOfTheKeythree_final_teams.head(20).to_csv('processed/teams/LeftOfTheKeythree_final_teams.csv')

 
TopOfTheKeythree_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Top of the key 3pt')]
#RightOfTheKeythree['team'].value_counts()


TopOfTheKeythree_grouped_teams = TopOfTheKeythree_df_teams.groupby('team')
madeTopOfTheKeythree = TopOfTheKeythree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopOfTheKeyThree = TopOfTheKeythree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

TopOfTheKeythree_final_teams = pd.concat([madeTopOfTheKeythree,totalTopOfTheKeyThree],axis ='columns').reset_index()
TopOfTheKeythree_final_teams['Percentage'] = TopOfTheKeythree_final_teams['made']/TopOfTheKeythree_final_teams['total']*100
TopOfTheKeythree_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopOfTheKeythree_final_teams.head(20).to_csv('processed/teams/TopOfTheKeythree_final_teams.csv')



RightCornerthree_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Right Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()
RightCornerthree_grouped_teams = RightCornerthree_df_teams.groupby('team')
madeRightCornerthree = RightCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightCornerThree = RightCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
RightCornerthree_final_teams = pd.concat([madeRightCornerthree,totalRightCornerThree],axis ='columns').reset_index()
RightCornerthree_final_teams['Percentage'] = RightCornerthree_final_teams['made']/RightCornerthree_final_teams['total']*100
RightCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightCornerthree_final_teams.head(20).to_csv('processed/teams/RightCornerTeams.csv')


 
LeftCornerthree_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Left Corner 3pt')]
#RightOfTheKeythree['team'].value_counts()


LeftCornerthree_grouped_teams = LeftCornerthree_df_teams.groupby('team')
madeLeftCornerthree = LeftCornerthree_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftCornerThree = LeftCornerthree_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftCornerthree_final_teams = pd.concat([madeLeftCornerthree,totalLeftCornerThree],axis ='columns').reset_index()
LeftCornerthree_final_teams['Percentage'] = LeftCornerthree_final_teams['made']/LeftCornerthree_final_teams['total']*100
LeftCornerthree_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftCornerthree_final_teams.head(20).to_csv('processed/teams/LeftCorner.csv')



 
Restricted_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()


Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20).to_csv('processed/teams/Restricted.csv')



 
Restricted_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Restricted')]
#RightOfTheKeythree['team'].value_counts()
Restricted_grouped_teams = Restricted_df_teams.groupby('team')
madeRestricted = Restricted_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRestricted = Restricted_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
Restricted_final_teams = pd.concat([madeRestricted,totalRestricted],axis ='columns').reset_index()
Restricted_final_teams['Percentage'] = Restricted_final_teams['made']/Restricted_final_teams['total']*100
Restricted_final_teams.sort_values(by='made', ascending=False, inplace=True)
Restricted_final_teams.head(20)




 
InsideThePaint_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Inside the paint')]
#RightOfTheKeythree['team'].value_counts()


InsideThePaint_grouped_teams = InsideThePaint_df_teams.groupby('team')
madeInsideThePaint = InsideThePaint_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalInsideThePaint = InsideThePaint_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

InsideThePaint_final_teams = pd.concat([madeInsideThePaint,totalInsideThePaint],axis ='columns').reset_index()
InsideThePaint_final_teams['Percentage'] = InsideThePaint_final_teams['made']/InsideThePaint_final_teams['total']*100
InsideThePaint_final_teams.sort_values(by='made', ascending=False, inplace=True)
InsideThePaint_final_teams.head(20).to_csv('processed/teams/InsidethePaint.csv')




 
RightMidrange_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Right midrange')]
#RightOfTheKeythree['team'].value_counts()


RightMidrange_grouped_teams = RightMidrange_df_teams.groupby('team')
madeRightMidrange = RightMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalRightMidrange = RightMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

RightMidrange_final_teams = pd.concat([madeRightMidrange,totalRightMidrange],axis ='columns').reset_index()
RightMidrange_final_teams['Percentage'] = RightMidrange_final_teams['made']/RightMidrange_final_teams['total']*100
RightMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
RightMidrange_final_teams.head(20).to_csv('processed/teams/RightMidTeam.csv')


 
LeftMidrange_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Left midrange')]
#RightOfTheKeythree['team'].value_counts()


LeftMidrange_grouped_teams = LeftMidrange_df_teams.groupby('team')
madeLeftMidrange = LeftMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalLeftMidrange = LeftMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters

LeftMidrange_final_teams = pd.concat([madeLeftMidrange,totalLeftMidrange],axis ='columns').reset_index()
LeftMidrange_final_teams['Percentage'] = LeftMidrange_final_teams['made']/LeftMidrange_final_teams['total']*100
LeftMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
LeftMidrange_final_teams.head(20).to_csv('processed/teams/LeftMidrangeTeam.csv')




TopMidrange_df_teams = CriteriaNOTbig4.loc[CriteriaNOTbig4['zone'].str.contains('Top of the midrange')]
#RightOfTheKeythree['team'].value_counts()
TopMidrange_grouped_teams = TopMidrange_df_teams.groupby('team')
madeTopMidrange = TopMidrange_grouped_teams['made'].apply(lambda x: x.str.contains('made').sum())
totalTopMidrange = TopMidrange_df_teams.groupby('team').size().to_frame('total')
#totalfloaters
TopMidrange_final_teams = pd.concat([madeTopMidrange,totalTopMidrange],axis ='columns').reset_index()
TopMidrange_final_teams['Percentage'] = TopMidrange_final_teams['made']/TopMidrange_final_teams['total']*100
TopMidrange_final_teams.sort_values(by='made', ascending=False, inplace=True)
TopMidrange_final_teams.head(20).to_csv('processed/teams/TopMidrange.csv')

LeftCornerthree_final_teams.head(20)
# Out:
#       team  made  total  Percentage
# 3  Sagesse    10     22   45.454545
# 2   Riyadi     7     13   53.846154
# 0   Beirut     5      9   55.555556
# 1   Dynamo     3      8   37.500000

# %%
JZ= TeamDF.loc[TeamDF['player'].str.contains('Zaloum')&TeamDF['zone'].str.contains('paint')]
regular_plot(JZ)
